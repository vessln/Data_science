# %%
import pandas as pd

import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # 1. Data collection

# %% [markdown]
# ## Overview
# In this notebook I collected information through web scraping. The data was scraped from two different websites for hotels, located in the Bulgarian Black Sea resort town Sozopol. The data from first website (https://hoteli-sozopol.pochivka.bg) is related to hotel details - stars, customers rating, price for double room, prices for triple room in the summer season and amenities that the hotel provides. The data from second website (https://booking.com) includes customer ratings and reviews - positive and negative.
#
# The data collected is intended only for educational and research purposes. It is not used for advertising, commercial purposes or any other misuse. The data is for demonstrating data analysis methods.

# %% [markdown]
# ## Web Scraping

# %% [markdown]
# ### Collect structured data
# The data was fetched on 12.08.2024 from https://hoteli-sozopol.pochivka.bg

# %% [markdown]
# The function extract_links_from_thumbs extract, process and retrieve all needed URLs from a specific webpage:

# %%
def extract_links_from_thumbs(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    
    thumb_divs = soup.find_all("div", class_="thumb")
    
    links = []
    for thumb in thumb_divs:
        link_tag = thumb.find("a", href=True)
        if link_tag:
            if "oferti" not in link_tag["href"].lower():
                if not link_tag["href"].startswith("https://"):
                    link_tag["href"] = f"https:{link_tag['href']}"
                    links.append(link_tag["href"])    
    return links

# %%
all_urls = [
    "https://hoteli-sozopol.pochivka.bg/1",
    "https://hoteli-sozopol.pochivka.bg/2",
    "https://hoteli-sozopol.pochivka.bg/3",
    "https://hoteli-sozopol.pochivka.bg/4",
    "https://hoteli-sozopol.pochivka.bg/5",
    "https://pochivka.bg/semeyni-hoteli-sozopol-t65",
    "https://pochivka.bg/semeyni-hoteli-sozopol-t65/2",
    "https://pochivka.bg/semeyni-hoteli-sozopol-t65/3",
    "https://pochivka.bg/semeyni-hoteli-sozopol-t65/4",
    "https://pochivka.bg/semeyni-hoteli-sozopol-t65/5",
    "https://pochivka.bg/semeyni-hoteli-sozopol-t65/6",
    "https://pochivka.bg/semeyni-hoteli-sozopol-t65/7",
    "https://pochivka.bg/semeyni-hoteli-sozopol-t65/8",
    "https://pochivka.bg/semeyni-hoteli-sozopol-t65/9",
    ]

all_links = []
for url in all_urls:
    all_links.extend(extract_links_from_thumbs(url))

# %%
len(all_links)
# Out:
# 259

# %%
unique_links = set(all_links)
len(unique_links)
# Out:
# 215

# %% [markdown]
# The function extract_hotel_details scrape and collect detailed information from a specific hotel webpage. It returns a dictionary containing extracted details:

# %%
def extract_hotel_details(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    
    hotel_name = soup.find("h1", itemprop="name").text.strip()
    location = soup.find("div", class_="sub-title").text.strip()
    
    rating = soup.find("span", class_="rating-score")
    rating = rating.text.strip() if rating else None

    hotels_reviews_links = {}
    review_link_tag = soup.find("a", itemprop="aggregateRating", class_="pull-right property-rating")
    review_link = review_link_tag["href"] if review_link_tag else None
    hotels_reviews_links[hotel_name] = review_link
    
    hotel_stars = soup.find("div", class_="rating")
    if hotel_stars: 
        star_spans = hotel_stars.find_all("span")
        stars_count = 5 - len([span for span in star_spans if "gray" in span["class"]])
    else:
        stars_count = None
    
    prices_table = soup.find("table", class_="prices") 
    
    room_type1, occupancy1, summer_price1 = None, None, None
    room_type2, occupancy2, summer_price2 = None, None, None
    room_type3, occupancy3, summer_price3 = None, None, None

    if prices_table:
        price_rows = prices_table.find_all("tr")
        room_type1 = price_rows[1].find_all("td")[0].text.strip()
        occupancy1 = price_rows[1].find_all("td")[1].text.strip()
        summer_price1 = price_rows[1].find_all("td")[3].text.strip()
       
        if len(price_rows) - 1 > 1:
            room_type2 = price_rows[2].find_all("td")[0].text.strip()
            occupancy2 = price_rows[2].find_all("td")[1].text.strip()
            summer_price2 = price_rows[2].find_all("td")[3].text.strip()

        if len(price_rows) - 1 > 2:
            room_type3 = price_rows[3].find_all("td")[0].text.strip()
            occupancy3 = price_rows[3].find_all("td")[1].text.strip()
            summer_price3 = price_rows[3].find_all("td")[3].text.strip()
        
    amenities_list = []
    amenities_div = soup.find("div", class_="extras")
    if amenities_div:
        amenities_ul = amenities_div.find("ul")
        if amenities_ul:
            amenities = amenities_ul.find_all("li")
            for amenity in amenities:
                amenities_list.append(amenity.text.strip())
        
    extracted_hotel_details = {
        "hotel_name": hotel_name,
        "hotel_stars_count": stars_count,
        "location": location,
        "rating": rating,
        "room_type1": room_type1,
        "occupancy1": occupancy1,
        "summer_price1": summer_price1,
        "room_type2": room_type2,
        "occupancy2": occupancy2,
        "summer_price2": summer_price2,
        "room_type3": room_type3,
        "occupancy3": occupancy3,
        "summer_price3": summer_price3,
        "amenities_list": amenities_list,
    }

    return extracted_hotel_details, hotels_reviews_links

# %%
hotel_data = []
reviews_data = []

# iterate through links and extract details and reviews link for each hotel in current link (page)
for link in unique_links:
    hotel_details, hotels_reviews_links = extract_hotel_details(link)

    hotel_data.append(hotel_details)
    reviews_data.append(hotels_reviews_links)
    
    print(f"{hotel_details}")
    print(f" LINK: {hotels_reviews_links}\n")
# Out:
# {'hotel_name': 'Семеен хотел Къщата с кивито', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '70 лв', 'room_type2': 'стандартна стая', 'occupancy2': '4', 'summer_price2': '90 лв', 'room_type3': 'лукс стая', 'occupancy3': '2', 'summer_price3': '75 лв', 'amenities_list': ['барбекю', 'камина', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'мини-бар', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'гладене', 'електрическа кана']}
#  LINK: {'Семеен хотел Къщата с кивито': None}
#
# {'hotel_name': 'Хотел Антеа Сердика', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': '9.6', 'room_type1': 'апартамент', 'occupancy1': '2', 'summer_price1': '170 лв', 'room_type2': 'апартамент', 'occupancy2': '2', 'summer_price2': '200 лв', 'room_type3': 'лукс апартамент', 'occupancy3': '2', 'summer_price3': '200 лв', 'amenities_list': ['ресторант', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'електрическа кана', 'асансьор']}
#  LINK: {'Хотел Антеа Сердика': 'http://www.booking.com/reviews/bg/hotel/anteya-serdika.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Сънрайз', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.9', 'room_type1': 'апартамент', 'occupancy1': '3', 'summer_price1': '176 лв', 'room_type2': 'апартамент', 'occupancy2': '4', 'summer_price2': '195 лв', 'room_type3': 'апартамент', 'occupancy3': '5', 'summer_price3': '285 лв', 'amenities_list': ['открит басейн', 'паркинг', 'рент-а-кар', 'детски басейн', 'телевизор', 'сателитна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'пералня', 'тераса', 'изглед', 'ютия', 'кухненски бокс', 'плащане с карта', 'лятна градина']}
#  LINK: {'Хотел Сънрайз': 'http://www.booking.com/reviews/bg/hotel/sunrise-two-bedroom-apartment.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Комплекс Лазур', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '100 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '100 лв', 'room_type3': 'стандартна стая', 'occupancy3': '4', 'summer_price3': '120 лв', 'amenities_list': ['открит басейн', 'паркинг', 'детски басейн', 'барбекю', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'кухненски бокс', 'бизнес услуги', 'дом. любимци', 'бар-басейн', 'електрическа кана', 'готварска печка']}
#  LINK: {'Комплекс Лазур': None}
#
# {'hotel_name': 'Семеен хотел Бриз', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.1', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '135 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '156 лв', 'room_type3': 'студио', 'occupancy3': '3', 'summer_price3': '166 лв', 'amenities_list': ['паркинг', 'ресторант', 'сейф', 'детски кът', 'лоби бар', 'кафене', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'мини-бар', 'телефон', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'пране', 'гладене', 'плащане с карта']}
#  LINK: {'Семеен хотел Бриз': 'http://www.booking.com/reviews/bg/hotel/briz-sozopol.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Ефект Свети Мина', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': '9.0', 'room_type1': None, 'occupancy1': None, 'summer_price1': None, 'room_type2': None, 'occupancy2': None, 'summer_price2': None, 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['тенис на маса', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'изглед', 'ютия', 'сешоар', 'плащане с карта', 'лятна градина']}
#  LINK: {'Хотел Ефект Свети Мина': 'http://www.booking.com/reviews/bg/hotel/sveti-mina.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Роял Калисто', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.1', 'room_type1': 'лукс стая', 'occupancy1': '2', 'summer_price1': '220 лв', 'room_type2': 'апартамент', 'occupancy2': '4', 'summer_price2': '330 лв', 'room_type3': 'лукс апартамент', 'occupancy3': '6', 'summer_price3': '460 лв', 'amenities_list': ['открит басейн', 'паркинг', 'ресторант', 'сейф', 'детски кът', 'детски басейн', 'лоби бар', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'вана', 'ютия', 'сешоар', 'пране', 'гладене', 'плащане с карта', 'дом. любимци', 'кафе машина', 'лятна градина', 'електрическа кана']}
#  LINK: {'Хотел Роял Калисто': 'http://www.booking.com/reviews/bg/hotel/calisto.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Каса де Оро', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': '9.5', 'room_type1': 'апартамент', 'occupancy1': '3', 'summer_price1': '400 лв', 'room_type2': 'апартамент', 'occupancy2': '4', 'summer_price2': '600 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['паркинг', 'кафене', 'телевизор', 'кухня', 'сателитна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'плащане с карта', 'кафе машина', 'лятна градина', 'електрическа кана']}
#  LINK: {'Хотел Каса де Оро': 'http://www.booking.com/reviews/bg/hotel/casa-de-oro.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Антеа', 'hotel_stars_count': 4, 'location': 'Созопол', 'rating': '9.5', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '315 лв', 'room_type2': 'студио', 'occupancy2': '3', 'summer_price2': '415 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '515 лв', 'amenities_list': ['ресторант', 'фитнес', 'рент-а-кар', 'сауна', 'сейф', 'рум сервиз', 'детски кът', 'детски басейн', 'лоби бар', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'мини-бар', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'закрит басейн', 'вана', 'ютия', 'сешоар', 'пране', 'гладене', 'плащане с карта', 'хим. чистене', 'дом. любимци', 'кафе машина', 'достъп за инвалиди', 'SPA център', 'електрическа кана']}
#  LINK: {'Хотел Антеа': 'http://www.booking.com/reviews/bg/hotel/coral-sozopol.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Емилия', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.7', 'room_type1': 'стандартна стая', 'occupancy1': '1', 'summer_price1': '80 лв', 'room_type2': 'стандартна стая', 'occupancy2': '1', 'summer_price2': '80 лв', 'room_type3': 'студио', 'occupancy3': '3', 'summer_price3': '95 лв', 'amenities_list': ['паркинг', 'телевизор', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'мини-бар', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'гладене', 'кафе машина', 'лятна градина']}
#  LINK: {'Семеен хотел Емилия': 'http://www.booking.com/reviews/bg/hotel/family-emilia.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Студио Морски вълни', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': None, 'room_type1': 'студио', 'occupancy1': '3', 'summer_price1': '140 лв', 'room_type2': 'лукс апартамент', 'occupancy2': '6', 'summer_price2': '350 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['открит басейн', 'охрана', 'детски басейн', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'вана', 'сешоар', 'гараж', 'достъп за инвалиди', 'електрическа кана', 'асансьор']}
#  LINK: {'Студио Морски вълни': None}
#
# {'hotel_name': 'Хотел Табанов Бийч', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.4', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '180 лв', 'room_type2': 'студио', 'occupancy2': '3', 'summer_price2': '250 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '290 лв', 'amenities_list': ['открит басейн', 'рент-а-кар', 'сейф', 'джакузи', 'детски кът', 'детски басейн', 'лоби бар', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'ютия', 'сешоар', 'пране', 'плащане с карта', 'достъп за инвалиди']}
#  LINK: {'Хотел Табанов Бийч': 'http://www.booking.com/reviews/bg/hotel/tabanov-beach-hotel.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Каса дел Сол', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.5', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '139 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '198 лв', 'room_type3': 'студио', 'occupancy3': '2', 'summer_price3': '198 лв', 'amenities_list': ['паркинг', 'сейф', 'телевизор', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'пране', 'бизнес услуги', 'лятна градина', 'електрическа кана']}
#  LINK: {'Хотел Каса дел Сол': 'http://www.booking.com/reviews/bg/hotel/casa-del-sol-sozopol.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Вила Quiet Bay', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': '8.6', 'room_type1': None, 'occupancy1': None, 'summer_price1': None, 'room_type2': None, 'occupancy2': None, 'summer_price2': None, 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['открит басейн', 'паркинг', 'детски басейн', 'барбекю', 'телевизор', 'кухня', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'изглед', 'кухненски бокс', 'електрическа кана', 'готварска печка']}
#  LINK: {'Вила Quiet Bay': 'http://www.booking.com/reviews/bg/hotel/vila-quiet-bay.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Комплекс Аполон 1 и 2', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.2', 'room_type1': 'студио', 'occupancy1': '2', 'summer_price1': '160 лв', 'room_type2': 'апартамент', 'occupancy2': '3', 'summer_price2': '200 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '240 лв', 'amenities_list': ['открит басейн', 'паркинг', 'рент-а-кар', 'охрана', 'детски кът', 'детски басейн', 'тенис на маса', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'пране', 'гладене', 'плащане с карта', 'хим. чистене', 'дом. любимци', 'лятна градина', 'достъп за инвалиди', 'електрическа кана']}
#  LINK: {'Комплекс Аполон 1 и 2': 'http://www.booking.com/reviews/bg/hotel/apolon-complex.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Мирамар', 'hotel_stars_count': 4, 'location': 'Созопол', 'rating': '8.6', 'room_type1': 'стандартна стая', 'occupancy1': '1', 'summer_price1': '285 лв', 'room_type2': 'стандартна стая', 'occupancy2': '2', 'summer_price2': '285 лв', 'room_type3': 'студио', 'occupancy3': '3', 'summer_price3': '370 лв', 'amenities_list': ['открит басейн', 'ресторант', 'сейф', 'лоби бар', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'мини-бар', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'кухненски бокс', 'бар-басейн', 'достъп за инвалиди']}
#  LINK: {'Хотел Мирамар': 'http://www.booking.com/reviews/bg/hotel/miramar.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Апартаменти под наем Панорама', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.5', 'room_type1': 'апартамент', 'occupancy1': '4', 'summer_price1': '247 лв', 'room_type2': 'лукс апартамент', 'occupancy2': '5', 'summer_price2': '306 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['открит басейн', 'охрана', 'детски кът', 'детски басейн', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'пералня', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'плащане с карта', 'кафе машина', 'лятна градина', 'бар-басейн', 'достъп за инвалиди', 'електрическа кана']}
#  LINK: {'Апартаменти под наем Панорама': 'http://www.booking.com/reviews/bg/hotel/apartments-in-complex-panorama.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Ваканционно селище Санта Марина', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.3', 'room_type1': 'студио', 'occupancy1': '3', 'summer_price1': '172 лв', 'room_type2': 'апартамент', 'occupancy2': '4', 'summer_price2': '248 лв', 'room_type3': 'лукс апартамент', 'occupancy3': '6', 'summer_price3': '321 лв', 'amenities_list': ['открит басейн', 'паркинг', 'ресторант', 'нощен бар', 'фитнес', 'билярд', 'тенис корт', 'рент-а-кар', 'аниматори', 'охрана', 'сауна', 'джакузи', 'детски кът', 'детски басейн', 'конферентна зала', 'солариум', 'студио за масаж', 'парна баня', 'интернет клуб', 'кафене', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'изглед', 'вана', 'ютия', 'обменно бюро', 'кухненски бокс', 'пране', 'гладене', 'плащане с карта', 'фризьорски салон', 'хим. чистене', 'волейбол', 'футбол', 'лятна градина', 'лекарски кабинет', 'бар-басейн', 'електрическа кана']}
#  LINK: {'Ваканционно селище Санта Марина': 'http://www.booking.com/reviews/bg/hotel/santa-marina.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Флагман', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '7.6', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '244 лв', 'room_type2': 'студио', 'occupancy2': '2', 'summer_price2': '250 лв', 'room_type3': 'апартамент', 'occupancy3': '2', 'summer_price3': '258 лв', 'amenities_list': ['открит басейн', 'ресторант', 'рент-а-кар', 'сейф', 'рум сервиз', 'детски басейн', 'конферентна зала', 'лоби бар', 'телевизор', 'сателитна тв', 'климатик', 'хладилник', 'мини-бар', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'обменно бюро', 'плащане с карта', 'дом. любимци']}
#  LINK: {'Хотел Флагман': 'http://www.booking.com/reviews/bg/hotel/flagman.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Апартамент Б18 Созополи Хилс', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.4', 'room_type1': 'апартамент', 'occupancy1': '6', 'summer_price1': '290 лв', 'room_type2': None, 'occupancy2': None, 'summer_price2': None, 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['открит басейн', 'паркинг', 'фитнес', 'охрана', 'детски басейн', 'барбекю', 'телевизор', 'кухня', 'кабелна тв', 'сателитна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'пералня', 'тераса', 'изглед', 'вана', 'ютия', 'сешоар', 'кафе машина', 'лятна градина', 'съдомиялна', 'електрическа кана', 'готварска печка']}
#  LINK: {'Апартамент Б18 Созополи Хилс': 'http://www.booking.com/reviews/bg/hotel/sozopoli-hills-apartament-b18-sozopoli-khils.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Къща Арес', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.1', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '80 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '120 лв', 'room_type3': 'студио', 'occupancy3': '4', 'summer_price3': '160 лв', 'amenities_list': ['телевизор', 'кабелна тв', 'сателитна тв', 'хазяи', 'климатик', 'хладилник', 'мини-бар', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'ютия', 'кухненски бокс', 'електрическа кана']}
#  LINK: {'Къща Арес': 'http://www.booking.com/reviews/bg/hotel/ares.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Елинор', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '60 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '70 лв', 'room_type3': 'студио', 'occupancy3': '4', 'summer_price3': '60 лв', 'amenities_list': ['паркинг', 'ресторант', 'кафене', 'телевизор', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар']}
#  LINK: {'Семеен хотел Елинор': None}
#
# {'hotel_name': 'Семеен хотел Фемили', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '60 лв', 'room_type2': 'студио', 'occupancy2': '3', 'summer_price2': '70 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '80 лв', 'amenities_list': ['паркинг', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'мини-бар', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'кухненски бокс', 'пране', 'гладене', 'кафе машина']}
#  LINK: {'Семеен хотел Фемили': None}
#
# {'hotel_name': 'Дом Делииванов', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '30 лв', 'room_type2': 'лукс стая', 'occupancy2': '2', 'summer_price2': '45 лв', 'room_type3': 'студио', 'occupancy3': '3', 'summer_price3': '54 лв', 'amenities_list': ['кухня', 'кабелна тв', 'климатик', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'кухненски бокс', 'SPA център']}
#  LINK: {'Дом Делииванов': None}
#
# {'hotel_name': 'Семеен хотел Сий Сенс', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.7', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '359 лв', 'room_type2': 'стандартна стая', 'occupancy2': '2', 'summer_price2': '416 лв', 'room_type3': 'лукс стая', 'occupancy3': '2', 'summer_price3': '458 лв', 'amenities_list': ['открит басейн', 'паркинг', 'сейф', 'студио за масаж', 'телевизор', 'кабелна тв', 'климатик', 'отопление', 'мини-бар', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'плащане с карта']}
#  LINK: {'Семеен хотел Сий Сенс': 'http://www.booking.com/reviews/bg/hotel/sea-sense-boutique.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семейна къща Лулеви', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '1', 'summer_price1': '40 лв', 'room_type2': 'стандартна стая', 'occupancy2': '2', 'summer_price2': '80 лв', 'room_type3': 'стандартна стая', 'occupancy3': '2', 'summer_price3': '60 лв', 'amenities_list': ['телевизор', 'кабелна тв', 'хазяи', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'ютия']}
#  LINK: {'Семейна къща Лулеви': None}
#
# {'hotel_name': 'Апартамент А19 в Созополи хилс', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.9', 'room_type1': 'студио', 'occupancy1': '3', 'summer_price1': '150 лв', 'room_type2': 'апартамент', 'occupancy2': '4', 'summer_price2': '195 лв', 'room_type3': 'апартамент', 'occupancy3': '6', 'summer_price3': '300 лв', 'amenities_list': ['открит басейн', 'паркинг', 'фитнес', 'детски кът', 'детски басейн', 'барбекю', 'телевизор', 'кухня', 'кабелна тв', 'сателитна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'пералня', 'тераса', 'изглед', 'радио', 'ютия', 'сешоар', 'кухненски бокс', 'кафе машина', 'лятна градина', 'съдомиялна', 'електрическа кана', 'готварска печка']}
#  LINK: {'Апартамент А19 в Созополи хилс': 'http://www.booking.com/reviews/bg/hotel/apartament-a19.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Долфин Бей Созопол', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': '9.7', 'room_type1': 'студио', 'occupancy1': '2', 'summer_price1': '290 лв', 'room_type2': 'лукс апартамент', 'occupancy2': '4', 'summer_price2': '380 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['открит басейн', 'паркинг', 'рум сервиз', 'детски басейн', 'барбекю', 'кафене', 'телевизор', 'кухня', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'сешоар', 'пране', 'плащане с карта', 'бар-басейн', 'електрическа кана', 'готварска печка']}
#  LINK: {'Хотел Долфин Бей Созопол': 'http://www.booking.com/reviews/bg/hotel/dolphin-bay-boutique-sozopol.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Ели', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '50 лв', 'room_type2': 'апартамент', 'occupancy2': '4', 'summer_price2': '90 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия']}
#  LINK: {'Семеен хотел Ели': None}
#
# {'hotel_name': 'Хотел Боруна', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '100 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '150 лв', 'room_type3': 'студио', 'occupancy3': '4', 'summer_price3': '140 лв', 'amenities_list': ['паркинг', 'ресторант', 'телевизор', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'баня/тоалетна', 'тераса', 'изглед', 'лятна градина', 'механа', 'електрическа кана']}
#  LINK: {'Хотел Боруна': None}
#
# {'hotel_name': 'Хотел Дриймс', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': None, 'room_type1': 'апартамент', 'occupancy1': '4', 'summer_price1': '100 лв', 'room_type2': None, 'occupancy2': None, 'summer_price2': None, 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['паркинг', 'ресторант', 'охрана', 'сейф', 'детски кът', 'тенис на маса', 'лоби бар', 'кафене', 'телевизор', 'кухня', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'микровълнова', 'пералня', 'тераса', 'изглед', 'вана', 'ютия', 'сешоар']}
#  LINK: {'Хотел Дриймс': None}
#
# {'hotel_name': 'Дом Атанасови', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '90 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '120 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'мини-бар', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'радио', 'ютия', 'пране']}
#  LINK: {'Дом Атанасови': None}
#
# {'hotel_name': 'Стаи за гости Мелиа Мар', 'hotel_stars_count': 1, 'location': 'Созопол', 'rating': '9.5', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '180 лв', 'room_type2': 'апартамент', 'occupancy2': '4', 'summer_price2': '210 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['открит басейн', 'паркинг', 'детски кът', 'детски басейн', 'телевизор', 'кабелна тв', 'климатик', 'интернет', 'баня/тоалетна', 'изглед', 'сешоар']}
#  LINK: {'Стаи за гости Мелиа Мар': 'http://www.booking.com/reviews/bg/hotel/melia-mar.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Орион', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.1', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '100 лв', 'room_type2': 'лукс стая', 'occupancy2': '2', 'summer_price2': '120 лв', 'room_type3': 'апартамент', 'occupancy3': '2', 'summer_price3': '110 лв', 'amenities_list': ['ресторант', 'сейф', 'рум сервиз', 'детски кът', 'кафене', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'пране', 'гладене', 'електрическа кана']}
#  LINK: {'Семеен хотел Орион': 'http://www.booking.com/reviews/bg/hotel/orion.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Серена Резиденс', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '7.2', 'room_type1': 'студио', 'occupancy1': '2', 'summer_price1': '218 лв', 'room_type2': 'апартамент', 'occupancy2': '2', 'summer_price2': '232 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['открит басейн', 'паркинг', 'ресторант', 'фитнес', 'рент-а-кар', 'аниматори', 'охрана', 'сейф', 'детски кът', 'детски басейн', 'барбекю', 'колела под наем', 'конферентна зала', 'тенис на маса', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'вана', 'ютия', 'сешоар', 'кухненски бокс', 'гладене', 'плащане с карта', 'бизнес услуги', 'хим. чистене', 'волейбол', 'футбол', 'бар-басейн', 'електрическа кана']}
#  LINK: {'Хотел Серена Резиденс': 'http://www.booking.com/reviews/bg/hotel/aparthotel.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Лагуна Бийч', 'hotel_stars_count': 4, 'location': 'Созопол', 'rating': '7.5', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '380 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '532 лв', 'room_type3': 'лукс стая', 'occupancy3': '2', 'summer_price3': '400 лв', 'amenities_list': ['открит басейн', 'паркинг', 'ресторант', 'фитнес', 'билярд', 'рент-а-кар', 'аниматори', 'охрана', 'сауна', 'сейф', 'джакузи', 'рум сервиз', 'детски кът', 'детски басейн', 'колела под наем', 'конферентна зала', 'козметик', 'тенис на маса', 'лоби бар', 'студио за масаж', 'парна баня', 'кафене', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'отопление', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'микровълнова', 'пералня', 'тераса', 'изглед', 'закрит басейн', 'фризьор', 'вана', 'ютия', 'сешоар', 'кухненски бокс', 'пране', 'гладене', 'плащане с карта', 'фризьорски салон', 'бизнес услуги', 'лятна градина', 'бар-басейн', 'достъп за инвалиди', 'SPA център']}
#  LINK: {'Хотел Лагуна Бийч': 'http://www.booking.com/reviews/bg/hotel/laguna-beach-resort-spa.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Коминеви', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '60 лв', 'room_type2': 'стандартна стая', 'occupancy2': '2', 'summer_price2': '60 лв', 'room_type3': 'студио', 'occupancy3': '3', 'summer_price3': '85 лв', 'amenities_list': ['телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'пералня', 'тераса', 'ютия', 'електрическа кана']}
#  LINK: {'Семеен хотел Коминеви': None}
#
# {'hotel_name': 'Семеен хотел Лилия', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.5', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '85 лв', 'room_type2': 'апартамент', 'occupancy2': '2', 'summer_price2': '105 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['паркинг', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'кухненски бокс', 'дом. любимци', 'електрическа кана']}
#  LINK: {'Семеен хотел Лилия': 'http://www.booking.com/reviews/bg/hotel/guest-house-liliya.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Сеемен хотел Музите', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.8', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '128 лв', 'room_type2': 'студио', 'occupancy2': '2', 'summer_price2': '136 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '190 лв', 'amenities_list': ['открит басейн', 'паркинг', 'ресторант', 'сейф', 'детски кът', 'детски басейн', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'мини-бар', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'пране', 'плащане с карта', 'лятна градина', 'бар-басейн', 'SPA център']}
#  LINK: {'Сеемен хотел Музите': 'http://www.booking.com/reviews/bg/hotel/muses.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Къща за гости Феникс', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': '10.0', 'room_type1': 'къща', 'occupancy1': '14', 'summer_price1': 'не се дава', 'room_type2': 'студио', 'occupancy2': '4', 'summer_price2': '165 лв', 'room_type3': 'студио', 'occupancy3': '4', 'summer_price3': '120 лв', 'amenities_list': ['барбекю', 'камина', 'телевизор', 'кухня', 'кабелна тв', 'сателитна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'пералня', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'кафе машина', 'механа', 'съдомиялна', 'електрическа кана', 'готварска печка', 'сушилня']}
#  LINK: {'Къща за гости Феникс': 'http://www.booking.com/reviews/bg/hotel/kshcha-za-gosti-feniks-sozopol.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Петрови', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': '8.3', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '80 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '90 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '110 лв', 'amenities_list': ['телевизор', 'кухня', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'изглед', 'кухненски бокс']}
#  LINK: {'Семеен хотел Петрови': 'http://www.booking.com/reviews/bg/hotel/guest-house-petrovi-sozopol.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Къща ГуудРест Созопол', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': None, 'room_type1': 'къща', 'occupancy1': '7', 'summer_price1': '300 лв', 'room_type2': None, 'occupancy2': None, 'summer_price2': None, 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['сауна', 'камина', 'телевизор', 'кухня', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'пералня', 'тераса', 'изглед', 'DVD', 'ютия', 'съдомиялна', 'електрическа кана', 'готварска печка']}
#  LINK: {'Къща ГуудРест Созопол': None}
#
# {'hotel_name': 'Къща Елена', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '75 лв', 'room_type2': 'стандартна стая', 'occupancy2': '2', 'summer_price2': '80 лв', 'room_type3': 'стандартна стая', 'occupancy3': '3', 'summer_price3': '90 лв', 'amenities_list': ['паркинг', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'баня/тоалетна', 'тераса', 'ютия', 'лятна градина', 'електрическа кана']}
#  LINK: {'Къща Елена': None}
#
# {'hotel_name': 'Хотел Силвър', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.0', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '130 лв', 'room_type2': 'апартамент', 'occupancy2': '5', 'summer_price2': '230 лв', 'room_type3': 'лукс апартамент', 'occupancy3': '5', 'summer_price3': '250 лв', 'amenities_list': ['открит басейн', 'паркинг', 'детски басейн', 'телевизор', 'кухня', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'кафе машина', 'електрическа кана', 'готварска печка']}
#  LINK: {'Хотел Силвър': 'http://www.booking.com/reviews/bg/hotel/silver-sozopol.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Дом Сотирови', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '40 лв', 'room_type2': 'апартамент', 'occupancy2': '4', 'summer_price2': '80 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['сейф', 'телевизор', 'кабелна тв', 'хладилник', 'мини-бар', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'SPA център']}
#  LINK: {'Семеен хотел Дом Сотирови': None}
#
# {'hotel_name': 'Апартаменти Калоян', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.9', 'room_type1': 'студио', 'occupancy1': '4', 'summer_price1': '135 лв', 'room_type2': 'студио', 'occupancy2': '4', 'summer_price2': '100 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '160 лв', 'amenities_list': ['паркинг', 'ресторант', 'сейф', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'пералня', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'пране', 'лятна градина', 'механа', 'електрическа кана', 'готварска печка']}
#  LINK: {'Апартаменти Калоян': 'http://www.booking.com/reviews/bg/hotel/apartments-kaloyan.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Калитея', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.1', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '153 лв', 'room_type2': 'лукс стая', 'occupancy2': '2', 'summer_price2': '165 лв', 'room_type3': 'студио', 'occupancy3': '3', 'summer_price3': '208 лв', 'amenities_list': ['ресторант', 'сейф', 'детски кът', 'колела под наем', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'пране']}
#  LINK: {'Хотел Калитея': 'http://www.booking.com/reviews/bg/hotel/kalithea.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Орка', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '90 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '130 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '160 лв', 'amenities_list': ['телевизор', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'кухненски бокс', 'електрическа кана']}
#  LINK: {'Семеен хотел Орка': None}
#
# {'hotel_name': 'Къща Ани', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': '9.1', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '120 лв', 'room_type2': 'стандартна стая', 'occupancy2': '2', 'summer_price2': '100 лв', 'room_type3': 'стандартна стая', 'occupancy3': '2', 'summer_price3': '85 лв', 'amenities_list': ['телевизор', 'кабелна тв', 'климатик', 'мини-бар', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'електрическа кана']}
#  LINK: {'Къща Ани': 'http://www.booking.com/reviews/bg/hotel/kshcha-za-gosti-ani.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Аквамарин', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.9', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '138 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '194 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['фитнес', 'сейф', 'студио за масаж', 'телевизор', 'кабелна тв', 'климатик', 'отопление', 'мини-бар', 'интернет', 'баня/тоалетна', 'пералня', 'ютия', 'сешоар', 'пране', 'плащане с карта']}
#  LINK: {'Хотел Аквамарин': 'http://www.booking.com/reviews/bg/hotel/aquamarine-sozopol.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Венис', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': '8.3', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '72 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '85 лв', 'room_type3': 'студио', 'occupancy3': '4', 'summer_price3': '120 лв', 'amenities_list': ['рент-а-кар', 'барбекю', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'кафе машина', 'лятна градина', 'електрическа кана']}
#  LINK: {'Семеен хотел Венис': 'http://www.booking.com/reviews/bg/hotel/venis.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Плавас', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.1', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '80 лв', 'room_type2': 'апартамент', 'occupancy2': '3', 'summer_price2': '210 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['паркинг', 'екскурзовод', 'рум сервиз', 'детски кът', 'барбекю', 'колела под наем', 'кафене', 'камина', 'телевизор', 'кухня', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'мини-бар', 'интернет', 'баня/тоалетна', 'пералня', 'тераса', 'изглед', 'вана', 'радио', 'ютия', 'сешоар', 'кухненски бокс', 'пране', 'гладене', 'дом. любимци', 'кафе машина', 'лятна градина']}
#  LINK: {'Семеен хотел Плавас': 'http://www.booking.com/reviews/bg/hotel/guest-house-plavas.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Алфа Вита', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.6', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '108 лв', 'room_type2': 'лукс стая', 'occupancy2': '2', 'summer_price2': '118 лв', 'room_type3': 'студио', 'occupancy3': '3', 'summer_price3': '138 лв', 'amenities_list': ['паркинг', 'ресторант', 'екскурзовод', 'рент-а-кар', 'охрана', 'сейф', 'рум сервиз', 'тенис на маса', 'кафене', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'мини-бар', 'телефон', 'интернет', 'баня/тоалетна', 'пералня', 'тераса', 'изглед', 'вана', 'ютия', 'сешоар', 'обменно бюро', 'пране', 'гладене', 'плащане с карта', 'лятна градина', 'достъп за инвалиди']}
#  LINK: {'Хотел Алфа Вита': 'http://www.booking.com/reviews/bg/hotel/alfa-vita.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Апартхотел Мартинез', 'hotel_stars_count': 4, 'location': 'Созопол', 'rating': '8.8', 'room_type1': 'студио', 'occupancy1': '2', 'summer_price1': '172 лв', 'room_type2': 'апартамент', 'occupancy2': '4', 'summer_price2': '242 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['открит басейн', 'паркинг', 'ресторант', 'нощен бар', 'фитнес', 'билярд', 'рент-а-кар', 'аниматори', 'охрана', 'сауна', 'сейф', 'рум сервиз', 'детски кът', 'детски басейн', 'конферентна зала', 'козметик', 'тенис на маса', 'лоби бар', 'студио за масаж', 'кафене', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'отопление', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'микровълнова', 'пералня', 'тераса', 'изглед', 'закрит басейн', 'вана', 'ютия', 'сешоар', 'обменно бюро', 'кухненски бокс', 'пране', 'гладене', 'плащане с карта', 'бизнес услуги', 'мини голф', 'хим. чистене', 'лятна градина', 'лекарски кабинет', 'бар-басейн', 'достъп за инвалиди']}
#  LINK: {'Апартхотел Мартинез': 'http://www.booking.com/reviews/bg/hotel/martinez.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Морска вила', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '70 лв', 'room_type2': 'студио', 'occupancy2': '4', 'summer_price2': '95 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '130 лв', 'amenities_list': ['открит басейн', 'паркинг', 'рент-а-кар', 'сейф', 'детски кът', 'детски басейн', 'барбекю', 'колела под наем', 'кафене', 'телевизор', 'сателитна тв', 'климатик', 'хладилник', 'мини-бар', 'интернет', 'баня/тоалетна', 'пералня', 'изглед', 'ютия']}
#  LINK: {'Семеен хотел Морска вила': None}
#
# {'hotel_name': 'Къща за гости Каса Бранка', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': '7.4', 'room_type1': 'стандартна стая', 'occupancy1': '1', 'summer_price1': '60 лв', 'room_type2': 'стандартна стая', 'occupancy2': '2', 'summer_price2': 'не се дава', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['телевизор', 'кухня', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'пералня', 'тераса', 'изглед', 'ютия', 'сешоар', 'кафе машина', 'лятна градина', 'електрическа кана', 'готварска печка']}
#  LINK: {'Къща за гости Каса Бранка': 'http://www.booking.com/reviews/bg/hotel/casa-branca.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Къща за гости в Созопол', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '100 лв', 'room_type2': 'лукс стая', 'occupancy2': '2', 'summer_price2': '110 лв', 'room_type3': 'студио', 'occupancy3': '4', 'summer_price3': '140 лв', 'amenities_list': ['паркинг', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар']}
#  LINK: {'Къща за гости в Созопол': None}
#
# {'hotel_name': 'Лунна пътека,100м плаж Хармани', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '80 лв', 'room_type2': 'стандартна стая', 'occupancy2': '2', 'summer_price2': '65 лв', 'room_type3': 'стандартна стая', 'occupancy3': '3', 'summer_price3': '100 лв', 'amenities_list': ['паркинг', 'барбекю', 'телевизор', 'климатик', 'мини-бар', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'кухненски бокс', 'достъп за инвалиди']}
#  LINK: {'Лунна пътека,100м плаж Хармани': None}
#
# {'hotel_name': 'Семеен хотел Вила Диана', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.7', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '90 лв', 'room_type2': 'апартамент', 'occupancy2': '4', 'summer_price2': '190 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['открит басейн', 'конна база', 'телевизор', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'ютия', 'кухненски бокс', 'гладене']}
#  LINK: {'Семеен хотел Вила Диана': 'http://www.booking.com/reviews/bg/hotel/villa-diana.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Вили Карен, Фиорд, Палома', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': None, 'room_type1': 'апартамент', 'occupancy1': '4', 'summer_price1': '140 лв', 'room_type2': 'апартамент', 'occupancy2': '5', 'summer_price2': '140 лв', 'room_type3': 'апартамент', 'occupancy3': '7', 'summer_price3': '200 лв', 'amenities_list': ['открит басейн', 'паркинг', 'детски басейн', 'телевизор', 'кухня', 'сателитна тв', 'климатик', 'хладилник', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'кухненски бокс']}
#  LINK: {'Вили Карен, Фиорд, Палома': None}
#
# {'hotel_name': 'Семеен хотел Екзотик', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.7', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '60 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '80 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '120 лв', 'amenities_list': ['телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия']}
#  LINK: {'Семеен хотел Екзотик': 'http://www.booking.com/reviews/bg/hotel/exotic.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Дом Апостолови', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': '9.7', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '90 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '110 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '150 лв', 'amenities_list': ['телевизор', 'кухня', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'мини-бар', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'дом. любимци', 'кафе машина', 'лятна градина', 'електрическа кана', 'готварска печка']}
#  LINK: {'Дом Апостолови': 'http://www.booking.com/reviews/bg/hotel/dom-apostolovi.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Калипсо', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '70 лв', 'room_type2': None, 'occupancy2': None, 'summer_price2': None, 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'кафе машина']}
#  LINK: {'Семеен хотел Калипсо': None}
#
# {'hotel_name': 'Вила Св. Анна', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '100 лв', 'room_type2': 'студио', 'occupancy2': '3', 'summer_price2': '120 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['паркинг', 'детски кът', 'барбекю', 'телевизор', 'кухня', 'кабелна тв', 'хазяи', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'кухненски бокс', 'кафе машина', 'лятна градина', 'съдомиялна', 'електрическа кана', 'готварска печка']}
#  LINK: {'Вила Св. Анна': None}
#
# {'hotel_name': 'Хотел Централ', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '1', 'summer_price1': '45 лв', 'room_type2': 'стандартна стая', 'occupancy2': '2', 'summer_price2': '90 лв', 'room_type3': 'стандартна стая', 'occupancy3': '3', 'summer_price3': '120 лв', 'amenities_list': ['открит басейн', 'паркинг', 'ресторант', 'аниматори', 'сейф', 'детски кът', 'детски басейн', 'барбекю', 'кафене', 'телевизор', 'кабелна тв', 'климатик', 'интернет', 'баня/тоалетна', 'тераса', 'ютия', 'плащане с карта', 'дом. любимци', 'лятна градина', 'бар-басейн']}
#  LINK: {'Хотел Централ': None}
#
# {'hotel_name': 'Къща Лозенград', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '70 лв', 'room_type2': 'студио', 'occupancy2': '4', 'summer_price2': '120 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['телевизор', 'кабелна тв', 'хазяи', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'ютия', 'сешоар', 'кухненски бокс', 'електрическа кана']}
#  LINK: {'Къща Лозенград': None}
#
# {'hotel_name': 'Семеен хотел Радиана', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.9', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '150 лв', 'room_type2': 'лукс стая', 'occupancy2': '2', 'summer_price2': '250 лв', 'room_type3': 'студио', 'occupancy3': '2', 'summer_price3': '210 лв', 'amenities_list': ['паркинг', 'рент-а-кар', 'джакузи', 'колела под наем', 'телевизор', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'мини-бар', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'пране', 'гладене', 'кафе машина']}
#  LINK: {'Семеен хотел Радиана': 'http://www.booking.com/reviews/bg/hotel/family-radiana.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Къща Kатерков', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': '9.1', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '120 лв', 'room_type2': 'студио', 'occupancy2': '2', 'summer_price2': '140 лв', 'room_type3': 'студио', 'occupancy3': '3', 'summer_price3': '155 лв', 'amenities_list': ['телевизор', 'кухня', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'пералня', 'тераса', 'изглед', 'ютия', 'кухненски бокс', 'кафе машина', 'лятна градина', 'електрическа кана', 'готварска печка']}
#  LINK: {'Къща Kатерков': 'http://www.booking.com/reviews/bg/hotel/kshcha-katerkov.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Александра', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '60 лв', 'room_type2': 'апартамент', 'occupancy2': '4', 'summer_price2': '80 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'ютия', 'електрическа кана']}
#  LINK: {'Семеен хотел Александра': None}
#
# {'hotel_name': 'Семеен хотел Софи', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.4', 'room_type1': 'стандартна стая', 'occupancy1': '1', 'summer_price1': '80 лв', 'room_type2': 'стандартна стая', 'occupancy2': '2', 'summer_price2': '115 лв', 'room_type3': 'стандартна стая', 'occupancy3': '3', 'summer_price3': '160 лв', 'amenities_list': ['открит басейн', 'рент-а-кар', 'сейф', 'колела под наем', 'студио за масаж', 'кафене', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'пране', 'гладене', 'плащане с карта', 'кафе машина', 'лятна градина']}
#  LINK: {'Семеен хотел Софи': 'http://www.booking.com/reviews/bg/hotel/arena-sozopol.bg.html?aid=343961&lang=bg'}
#
# ...
#  LINK: {'Апартамент в Грийн Лайф морска гледка': 'http://www.booking.com/reviews/bg/hotel/green-life-beach-resort-paradise-apartment.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Вила Роси', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.3', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '94 лв', 'room_type2': 'студио', 'occupancy2': '3', 'summer_price2': '148 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '186 лв', 'amenities_list': ['паркинг', 'сейф', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'пране', 'кафе машина', 'лятна градина', 'електрическа кана']}
#  LINK: {'Вила Роси': 'http://www.booking.com/reviews/bg/hotel/villa-rosi.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Блу Ориндж', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': '8.2', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '210 лв', 'room_type2': None, 'occupancy2': None, 'summer_price2': None, 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['открит басейн', 'паркинг', 'ресторант', 'аниматори', 'сейф', 'рум сервиз', 'детски кът', 'детски басейн', 'барбекю', 'лоби бар', 'телевизор', 'сателитна тв', 'климатик', 'хладилник', 'мини-бар', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'закрит басейн', 'сешоар', 'обменно бюро', 'плащане с карта', 'бар-басейн', 'достъп за инвалиди', 'SPA център']}
#  LINK: {'Хотел Блу Ориндж': 'http://www.booking.com/reviews/bg/hotel/blue-orange-beach-resort.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Вила Вега', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.6', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '55 лв', 'room_type2': 'апартамент', 'occupancy2': '4', 'summer_price2': '100 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['открит басейн', 'паркинг', 'джакузи', 'детски кът', 'детски басейн', 'барбекю', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'мини-бар', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'гладене', 'достъп за инвалиди']}
#  LINK: {'Вила Вега': 'http://www.booking.com/reviews/bg/hotel/villa-vega.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Барекс', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.0', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '126 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '144 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['открит басейн', 'ресторант', 'рент-а-кар', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'мини-бар', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'пране', 'плащане с карта', 'електрическа кана']}
#  LINK: {'Семеен хотел Барекс': 'http://www.booking.com/reviews/bg/hotel/barex-family.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Електра', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '45 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '55 лв', 'room_type3': 'студио', 'occupancy3': '4', 'summer_price3': '65 лв', 'amenities_list': ['паркинг', 'телевизор', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'мини-бар', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'ютия', 'лятна градина']}
#  LINK: {'Семеен хотел Електра': None}
#
# {'hotel_name': 'Семеен хотел Власта', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '60 лв', 'room_type2': 'студио', 'occupancy2': '3', 'summer_price2': '100 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['телевизор', 'кабелна тв', 'климатик', 'хладилник', 'мини-бар', 'интернет', 'баня/тоалетна', 'тераса', 'гладене']}
#  LINK: {'Семеен хотел Власта': None}
#
# {'hotel_name': 'Апартаменти Виа Понтика 123', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.9', 'room_type1': 'студио', 'occupancy1': '2', 'summer_price1': '160 лв', 'room_type2': 'апартамент', 'occupancy2': '2', 'summer_price2': '190 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '200 лв', 'amenities_list': ['открит басейн', 'паркинг', 'барбекю', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'кафе машина', 'електрическа кана']}
#  LINK: {'Апартаменти Виа Понтика 123': 'http://www.booking.com/reviews/bg/hotel/via-pontica-123-sozopol2.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Аполис', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.3', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '126 лв', 'room_type2': 'студио', 'occupancy2': '2', 'summer_price2': '139 лв', 'room_type3': 'мезонет', 'occupancy3': '2', 'summer_price3': '153 лв', 'amenities_list': ['открит басейн', 'паркинг', 'ресторант', 'рент-а-кар', 'детски кът', 'детски басейн', 'телевизор', 'сателитна тв', 'климатик', 'мини-бар', 'баня/тоалетна', 'тераса', 'изглед']}
#  LINK: {'Хотел Аполис': 'http://www.booking.com/reviews/bg/hotel/apolis.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Хасиенда Бийч', 'hotel_stars_count': 4, 'location': 'Созопол', 'rating': '7.6', 'room_type1': 'апартамент', 'occupancy1': '2', 'summer_price1': '220 лв', 'room_type2': 'апартамент', 'occupancy2': '3', 'summer_price2': '300 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '400 лв', 'amenities_list': ['открит басейн', 'паркинг', 'ресторант', 'охрана', 'сейф', 'детски кът', 'детски басейн', 'лоби бар', 'кафене', 'телевизор', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'радио', 'сешоар', 'пране', 'плащане с карта', 'дом. любимци', 'лятна градина', 'бар-басейн', 'достъп за инвалиди']}
#  LINK: {'Хотел Хасиенда Бийч': 'http://www.booking.com/reviews/bg/hotel/hacienda-beach.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Аиа', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.3', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '66 лв', 'room_type2': None, 'occupancy2': None, 'summer_price2': None, 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['паркинг', 'екскурзовод', 'рент-а-кар', 'сейф', 'барбекю', 'телевизор', 'кухня', 'климатик', 'хладилник', 'мини-бар', 'интернет', 'баня/тоалетна', 'микровълнова', 'тераса', 'ютия', 'сешоар', 'кухненски бокс', 'достъп за инвалиди']}
#  LINK: {'Семеен хотел Аиа': 'http://www.booking.com/reviews/bg/hotel/aia-sozopol.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Къща Кера до Централен плаж', 'hotel_stars_count': 2, 'location': 'Созопол', 'rating': '9.3', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '90 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '105 лв', 'room_type3': 'студио', 'occupancy3': '4', 'summer_price3': '130 лв', 'amenities_list': ['телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия']}
#  LINK: {'Къща Кера до Централен плаж': 'http://www.booking.com/reviews/bg/hotel/kera-family-house.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Комплекс Мапи Холидей', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.9', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '102 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '128 лв', 'room_type3': 'студио', 'occupancy3': '4', 'summer_price3': '160 лв', 'amenities_list': ['открит басейн', 'паркинг', 'ресторант', 'детски басейн', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'кухненски бокс']}
#  LINK: {'Комплекс Мапи Холидей': 'http://www.booking.com/reviews/bg/hotel/mappi-holiday-village.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Изток', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.0', 'room_type1': 'стандартна стая', 'occupancy1': '3', 'summer_price1': '80 лв', 'room_type2': 'студио', 'occupancy2': '2', 'summer_price2': '65 лв', 'room_type3': 'апартамент', 'occupancy3': '4', 'summer_price3': '105 лв', 'amenities_list': ['открит басейн', 'паркинг', 'джакузи', 'детски басейн', 'барбекю', 'телевизор', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'пералня', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'пране', 'гладене', 'кафе машина', 'лятна градина', 'достъп за инвалиди', 'електрическа кана']}
#  LINK: {'Семеен хотел Изток': 'http://www.booking.com/reviews/bg/hotel/vila-iztok.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Акшаена', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': '8.8', 'room_type1': 'стандартна стая', 'occupancy1': '3', 'summer_price1': '90 лв', 'room_type2': 'студио', 'occupancy2': '2', 'summer_price2': '80 лв', 'room_type3': 'студио', 'occupancy3': '4', 'summer_price3': '100 лв', 'amenities_list': ['открит басейн', 'барбекю', 'кафене', 'телевизор', 'сателитна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'пералня', 'тераса', 'изглед', 'ютия', 'кухненски бокс', 'дом. любимци']}
#  LINK: {'Семеен хотел Акшаена': 'http://www.booking.com/reviews/bg/hotel/akshaena.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Фиорд B&B', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.8', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '156 лв', 'room_type2': 'стандартна стая', 'occupancy2': '2', 'summer_price2': '148 лв', 'room_type3': 'лукс стая', 'occupancy3': '2', 'summer_price3': '168 лв', 'amenities_list': ['паркинг', 'сейф', 'лоби бар', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'вана', 'ютия', 'сешоар', 'пране', 'гладене', 'плащане с карта']}
#  LINK: {'Фиорд B&B': 'http://www.booking.com/reviews/bg/hotel/fjord.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Св. Зосим', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.1', 'room_type1': 'студио', 'occupancy1': '4', 'summer_price1': '180 лв', 'room_type2': 'лукс апартамент', 'occupancy2': '8', 'summer_price2': '440 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['паркинг', 'телевизор', 'кухня', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'микровълнова', 'пералня', 'тераса', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'достъп за инвалиди']}
#  LINK: {'Хотел Св. Зосим': 'http://www.booking.com/reviews/bg/hotel/sveti-zosim.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Лозите', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '8.1', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '140 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '150 лв', 'room_type3': 'лукс стая', 'occupancy3': '2', 'summer_price3': '180 лв', 'amenities_list': ['паркинг', 'рент-а-кар', 'сейф', 'детски кът', 'колела под наем', 'лоби бар', 'камина', 'телевизор', 'сателитна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'дом. любимци', 'лятна градина']}
#  LINK: {'Хотел Лозите': 'http://www.booking.com/reviews/bg/hotel/hotel-lozite.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Морска звезда', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '7.5', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '85 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '75 лв', 'room_type3': 'студио', 'occupancy3': '3', 'summer_price3': '120 лв', 'amenities_list': ['ресторант', 'сейф', 'телевизор', 'кабелна тв', 'климатик', 'отопление', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'микровълнова', 'изглед', 'ютия', 'сешоар', 'кухненски бокс', 'пране', 'гладене', 'плащане с карта', 'електрическа кана', 'готварска печка']}
#  LINK: {'Семеен хотел Морска звезда': 'http://www.booking.com/reviews/bg/hotel/morska-zvezda-sozopol.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Семеен хотел Свети Никола', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '9.3', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '110 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '120 лв', 'room_type3': 'лукс стая', 'occupancy3': '3', 'summer_price3': '140 лв', 'amenities_list': ['паркинг', 'ресторант', 'рент-а-кар', 'сейф', 'кафене', 'телевизор', 'кабелна тв', 'сателитна тв', 'климатик', 'отопление', 'хладилник', 'мини-бар', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'ютия', 'сешоар', 'гладене', 'плащане с карта', 'дом. любимци', 'лятна градина', 'достъп за инвалиди']}
#  LINK: {'Семеен хотел Свети Никола': 'http://www.booking.com/reviews/bg/hotel/sveti-nikola-kavaci.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Хотел Южна Перла', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '7.3', 'room_type1': 'студио', 'occupancy1': '2', 'summer_price1': '180 лв', 'room_type2': 'апартамент', 'occupancy2': '3', 'summer_price2': '290 лв', 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['открит басейн', 'паркинг', 'нощен бар', 'фитнес', 'екскурзовод', 'рент-а-кар', 'охрана', 'сауна', 'сейф', 'детски кът', 'детски басейн', 'лоби бар', 'студио за масаж', 'кафене', 'телевизор', 'кухня', 'сателитна тв', 'климатик', 'отопление', 'хладилник', 'телефон', 'интернет', 'баня/тоалетна', 'пералня', 'тераса', 'изглед', 'вана', 'радио', 'DVD', 'ютия', 'сешоар', 'кухненски бокс', 'пране', 'гладене', 'плащане с карта', 'бизнес услуги', 'хим. чистене', 'дом. любимци', 'достъп за инвалиди']}
#  LINK: {'Хотел Южна Перла': 'http://www.booking.com/reviews/bg/hotel/south-pearl-residence.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Вила Ананда', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': None, 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '130 лв', 'room_type2': None, 'occupancy2': None, 'summer_price2': None, 'room_type3': None, 'occupancy3': None, 'summer_price3': None, 'amenities_list': ['барбекю', 'кухня', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед', 'гараж', 'кафе машина', 'лятна градина']}
#  LINK: {'Вила Ананда': None}
#
# {'hotel_name': 'Хотел Рай', 'hotel_stars_count': 3, 'location': 'Созопол', 'rating': '6.8', 'room_type1': 'стандартна стая', 'occupancy1': '2', 'summer_price1': '150 лв', 'room_type2': 'стандартна стая', 'occupancy2': '3', 'summer_price2': '170 лв', 'room_type3': 'студио', 'occupancy3': '3', 'summer_price3': '175 лв', 'amenities_list': ['открит басейн', 'паркинг', 'ресторант', 'детски басейн', 'телевизор', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'тераса', 'изглед']}
#  LINK: {'Хотел Рай': 'http://www.booking.com/reviews/bg/hotel/sozopol.bg.html?aid=343961&lang=bg'}
#
# {'hotel_name': 'Вила Миа', 'hotel_stars_count': None, 'location': 'Созопол', 'rating': None, 'room_type1': 'къща', 'occupancy1': '11', 'summer_price1': '360 лв', 'room_type2': 'стандартна стая', 'occupancy2': '2', 'summer_price2': '90 лв', 'room_type3': 'лукс стая', 'occupancy3': '3', 'summer_price3': '140 лв', 'amenities_list': ['телевизор', 'кухня', 'кабелна тв', 'климатик', 'хладилник', 'интернет', 'баня/тоалетна', 'пералня', 'тераса', 'изглед', 'ютия']}
#  LINK: {'Вила Миа': None}

# %%
hotels_data = pd.DataFrame(hotel_data)

# %%
hotels_data.to_csv("data/hotels_data.csv", index = False)

# %%
hotels_data_df = pd.read_csv("data/hotels_data.csv")

# %% [markdown]
# ### Collect unstructured data
# Collect reviews for specific hotels are from booking.com

# %% [markdown]
# The function extracts latest 25 reviews (if there are 25 or more) and their ratings for each hotel:

# %%
def extract_review_details(current_hotel_info):
    for name, url in current_hotel_info.items():
        hotel_name, review_link = name, url

        if not review_link:
            continue 

        response = requests.get(review_link)
        soup = BeautifulSoup(response.content, "html.parser")

        review_containers = soup.find_all("div", class_ = "review_item_review_content")

        reviews = []
        for current_review in review_containers:
            if current_review.find("p", class_ = "review_none"):
                continue

            rating_value = None
            rating_element = soup.find('span', itemprop="reviewRating")
            if rating_element:
                rating_meta = rating_element.find('meta', itemprop="ratingValue")
                if rating_meta:
                    rating_value = rating_meta['content']

            pos_review_content = None
            neg_review_content = None

            for review_type in ["review_neg", "review_pos"]:
                review_section = current_review.find('p', class_=review_type)
                if review_section:
                    content_span = review_section.find("span", itemprop="reviewBody")
                    content = content_span.text.strip() if content_span else None
                    if review_type == "review_neg":
                        neg_review_content = content
                    else:
                        pos_review_content = content

            reviews.append({
                'hotel_name': hotel_name,
                'review_rating_score': rating_value,
                'pos_review_content': pos_review_content,
                'neg_review_content': neg_review_content
            })

        return reviews

# %%
all_reviews = []

for current_hotel_info in reviews_data:
    hotel_reviews = extract_review_details(current_hotel_info)
    if hotel_reviews:
        all_reviews.extend(hotel_reviews)
        # print(hotel_reviews)
# Out:
# [{'hotel_name': 'Комплекс Вили над залива', 'review_rating_score': '10', 'pos_review_content': 'Супер локация, много е удобна ако искате да посетите Exe beach bar.', 'neg_review_content': 'Широко и удобно, има паркомясто и удобна локация на тихо място.'}, {'hotel_name': 'Комплекс Вили над залива', 'review_rating_score': '10', 'pos_review_content': 'Уникално и любезно отношение от собствениците. Посрещнаха ни и ни изпратиха с усмивка. Нищо общо с отзивите оставени в booking. Истината е ,че рядко доволните клиенти пишат коментари, а напротив. Държи се на тишина и спокойствие, а не на купони и еуфории. Вилите са изключително приятно обзаведени, комфортни, уютни и чистички. Има всичко необходимо като оборудване в кухненския бокс и приятни местенца за хапване на открито. Има място за паркиране. Попитах за домашния си любимец и той не беше допуснат, но в последствие разбрахме, че си има и това адекватна и разбираема причина, а имено здравословна причина в семейството на собсвениците. Със сигурност бих посетила мястото отново и то за повече.', 'neg_review_content': 'Всичко беше супер. Нямам лош коментар!!!'}]
# [{'hotel_name': 'Семеен хотел Елена', 'review_rating_score': '9', 'pos_review_content': 'Стаята на живо е по-хубава от на снимките голяма , светла и чиста, домакиня също е любезен, заслужава си.', 'neg_review_content': None}, {'hotel_name': 'Семеен хотел Елена', 'review_rating_score': '9', 'pos_review_content': 'Топ локация', 'neg_review_content': None}, {'hotel_name': 'Семеен хотел Елена', 'review_rating_score': '9', 'pos_review_content': 'Благодаря за кафенцето, оставено в стаята', 'neg_review_content': None}, {'hotel_name': 'Семеен хотел Елена', 'review_rating_score': '9', 'pos_review_content': 'Локацията е супер. Точно на центъра в новия град. Всичко е наблизо. Чисто е и уютно. Банята беше ок, както и кърпите.', 'neg_review_content': 'Поне за мен ютията и дъската за гладене са важни. Това може да бъде подобрено.'}, {'hotel_name': 'Семеен хотел Елена', 'review_rating_score': '9', 'pos_review_content': 'Местоположение и обслужване много добри. Хубав интернет, въпреки централното разположение на вилата тихо и спокойно място за почивка.', 'neg_review_content': 'Препоръка: Сешоар и ютия на разположение на всяка стая.'}, {'hotel_name': 'Семеен хотел Елена', 'review_rating_score': '9', 'pos_review_content': None, 'neg_review_content': 'никъде не е обозначено,че паркинг се доплаща 15лв на ден'}]
# [{'hotel_name': 'Къща за гости Феникс', 'review_rating_score': '10', 'pos_review_content': 'Страхотна къща за почивка или събиране с приятели. Особено впечатляваща е механата с уютното огнище, което предразполага за създаване на много незабравими спомени със семейство или приятели! Също така домакините бяха изключително отзивчиви и всеотдайни, за да направят престоя ни максимално приятен и удобен.', 'neg_review_content': None}]
# [{'hotel_name': 'Вила Миа', 'review_rating_score': '10', 'pos_review_content': 'Хареса ми гледката на стаята към морето и спокойствието, което цари наоколо! Идеално място за почивка! Хареса ми изключително много чистотата в хотела и ежедневната подмяна на кърпи, принадлежности (сапуни, балсами за коса и душ гелове) и торба за боклук! Стаите са чисти и уникални за почивка!', 'neg_review_content': 'Не ми хареса, че водата в басейна е доста студена! През всички дни, които бяхме на басейн, само първата вечер що годе водата беше топла! Може би трябва да се помисли за нещо допълнително за отопляне! Не ми хареса черния път по който се стига - по него се кара около 700 метра. Не е осветено до самата вила и всички съседни на нея, така че вечерно време е хубаво да си с автомобил!'}, {'hotel_name': 'Вила Миа', 'review_rating_score': '10', 'pos_review_content': 'Прекрасно място, всичко ни хареса, ново, поддържано, с отзивчиви домакини. Стаите бяха чести, удобни, просторни, нищо не ни липсваше. Басейнът е чудесна алтернатива за отдих, ако не ви се отива до плажа. Чувстваш се като у дома си. \nЩе се върнем отново! 😊', 'neg_review_content': None}, {'hotel_name': 'Вила Миа', 'review_rating_score': '10', 'pos_review_content': 'Хотела е много хубав и чист, има предостатъчно паркоместа', 'neg_review_content': 'Единственото нещо което ми хвана окото като минус бяха баните. Нямаше чашка да си оставиш четката за зъби нямаше и рафтче около душа където да си оставиш козметиката'}, {'hotel_name': 'Вила Миа', 'review_rating_score': '10', 'pos_review_content': 'Спокойно и уютно място, на 10-15 минути от плаж Каваци. Чисто и подредено. Басейна също много ми допадна.', 'neg_review_content': 'Възглавниците лично за мен бяха неудобни, но това е въпрос на предпочитание.'}, {'hotel_name': 'Вила Миа', 'review_rating_score': '10', 'pos_review_content': 'Всичко беше супер.Персонала беше много мил.Изключително чисто', 'neg_review_content': None}, {'hotel_name': 'Вила Миа', 'review_rating_score': '10', 'pos_review_content': 'Приятно тихо хотелче, с хубава гледка. Студиото, в което отседнахме беше с добър размер и достатъчно пространство за всичко. Почистването е на много високо ниво.', 'neg_review_content': 'За да се стигне до плаж или заведение, Стария град, и т.н., трябва да се повърви доста пеша или да се използва кола/такси.'}, {'hotel_name': 'Вила Миа', 'review_rating_score': '10', 'pos_review_content': 'Добра локация, само на 10мин пеша от плажа. Безупречна чистота, комфорт в стаята с всичко необходимо. Басейнът е чист и поддържан. Персоналът е мил и вежлив, почистваха ни стаята всеки ден :) \nОстанахме много доволни и бихме се върнали отново!', 'neg_review_content': 'Повече посуда в кухнята би била от полза за хора, които си готвят предимно. :)'}, {'hotel_name': 'Вила Миа', 'review_rating_score': '10', 'pos_review_content': 'Беше много чистичко, отлична локация до всичко, което ми беше нужно за едно хубаво прекарване. Създава доста приятно чувство за комфорт!', 'neg_review_content': None}, {'hotel_name': 'Вила Миа', 'review_rating_score': '10', 'pos_review_content': 'Отдъхнахме си в тишина и спокойствие. Хотелът е прекрасно поддържан. Басейнът е чист и обзаведен с чадъри и шезлонги. Стаята беше чиста с ново обзавеждане. Леглото бе за нас с прерфектна ергономична твърдост и размер на Queen bed  - все пак не е само за сън  ;D ... Много ни хареса политиката на хотела за ежедневна смяна на хавлиите ! На рецепцията работеха две любезни и отзивчиви дами ! Бяхме забравили нещо от багажа си в стаята и потеглихме, а реакцията на младата дама от рецепцията бе светкавична, още преди да сме напуснали района на Буджака - за което сме много благодарни ! С няколко думи - перфектно място за ваканция ! \rАпропо, плажувахме на Смокиня - чист и поддържан плаж с платена част и свободна зона. \rАко дойдеш с добро настроение, с двойно такова ще си тръгнеш !', 'neg_review_content': 'Нямаше нещо което да ни подразни ! Всичко бе OK !'}, {'hotel_name': 'Вила Миа', 'review_rating_sco ...
# [{'hotel_name': 'Хотел Табанов Бийч', 'review_rating_score': '8', 'pos_review_content': 'Персонала беше мил ,локацията е на добро място !', 'neg_review_content': None}, {'hotel_name': 'Хотел Табанов Бийч', 'review_rating_score': '8', 'pos_review_content': 'Стаята се почистваше всеки ден, персонала беше усмихнат и приветлив. Местоположението на хотела е добро.', 'neg_review_content': 'Към основната цена нямаше включена закуска, което според мен е минус. Нямат свое паркомясто пред хотела, поне да разтоварите куфарите, а трябва да ги носите от паркинга, който е платен. Стаята, която ни бяха дали беше от към главния път и беше изключително шумно, дори нощем.'}, {'hotel_name': 'Хотел Табанов Бийч', 'review_rating_score': '8', 'pos_review_content': 'Много сме доволни, чисто, приветлив персонал, уютни стаи', 'neg_review_content': '.'}, {'hotel_name': 'Хотел Табанов Бийч', 'review_rating_score': '8', 'pos_review_content': 'Хората са изключително любезни и разбрани,наложи ни се да тръгнем с ден по-рано и те ни възстановиха последната нощувка с усмивка и без проблем!Локацията е изключително удобна,в близост до всички заведения и ресторанти,както и до плажа.', 'neg_review_content': None}, {'hotel_name': 'Хотел Табанов Бийч', 'review_rating_score': '8', 'pos_review_content': 'Чисто, усмихнат и услужлив персонал, на хубаво място. Бих го посетил пак!', 'neg_review_content': 'Няма нещо, което да не ми хареса!'}, {'hotel_name': 'Хотел Табанов Бийч', 'review_rating_score': '8', 'pos_review_content': 'Чистота и усмихнати домакини', 'neg_review_content': None}, {'hotel_name': 'Хотел Табанов Бийч', 'review_rating_score': '8', 'pos_review_content': 'Хотелът има много добра локация.', 'neg_review_content': 'За почти 200 лв за нощувка чистотата беше доста незадоволителна. Цялата баня беше в котлен камък. Имаше лепкави петна по пода и жълти петна по хавлиите за лице, което създаде изключително неприятно усещане. Няма паркинг, което е огромен минус. Ако решите да посетите малко по-далечен плаж с кола като Каваци или Градина, след 17 ч. е оргомен късмет да си намерите свободни места на близкия паркинг и се почва едно обикаляне... За парите, които платихме, нямаше дори включена закуска.   Спалнята не е спалня, а долепени 2 единични матрака, които постоянно се разместват. Преносимият сушилник на терасата беше ръждясал и банските ни се изцапаха. Определено не бихме повторили.'}, {'hotel_name': 'Хотел Табанов Бийч', 'review_rating_score': '8', 'pos_review_content': 'Niacho ne besche tova koeto pokazvate na snimki', 'neg_review_content': 'Ne mi haresa\nRestoranta ne rabotesche\nParking niama\nStaite ne se pochistvat vseki den\nBanite sascho\nBasena ne tozi koito e na snimkata'}, {'hotel_name': 'Хотел Табанов Бийч', 'review_rating_score': '8', 'pos_review_content': 'Страхотно място, супер локация, много добро обслужване и много чисто място,всичко беше супер😀', 'neg_review_content': None}, {'hotel_name': 'Хотел Табанов Бийч', 'review_rating_score': '8', 'pos_review_content': 'Местоположението е добро, близо до плажа и центъра.', 'neg_review_content': 'Стаята не беше добре почистена при пристигането ни, очаквахме king size bed, а в действителност бяха два долепени матрака, които се раздалечаваха и трябваше да се избутват обратно, което беше неприятно и досадно. В бяната имаше единствено сапун и шампоан в пликче като осигурени принадлежности. Не знаех, че хотелите все още предлагат такива… малко разочароващо за 60 лв на човек на вечер, дори нямаше душ гел, а със струята на душа може спокойно да си пробиеш дупка в кожата, а той друга настройка, за съжаление, няма. Интернетът не беше задоволителен.'}, {'hotel_name': 'Хотел Табанов Бийч', 'review_rating_score': '8', 'pos_review_content': 'Чист и спретнат хотел с всичко необходимо за спокойна почивка! Персоналът е много отзивчив и винаги усмихнат! Ще се върнем пак!', 'neg_review_content': None}, {'hotel_name': 'Хотел Табанов Бийч', 'review_rating_score': '8', 'pos_review_content': 'Чист и спокоен хотел с всичко нео ...
# [{'hotel_name': 'Хотел Руж', 'review_rating_score': '8', 'pos_review_content': 'Всичко беше прекрасно. Вилата е чиста, много добре подържана.  Басейна е чист. Гледката прекрасна', 'neg_review_content': None}, {'hotel_name': 'Хотел Руж', 'review_rating_score': '8', 'pos_review_content': 'Посещаваме втора година,всичко беше страхотно,спокойно място,страхотен апартамент,чисто,плаж на 1 минута,чист и голям басейн и чудесни домакини.', 'neg_review_content': None}, {'hotel_name': 'Хотел Руж', 'review_rating_score': '8', 'pos_review_content': 'Местоположението, оборудването и размерът на стаята.', 'neg_review_content': None}, {'hotel_name': 'Хотел Руж', 'review_rating_score': '8', 'pos_review_content': 'Разположението на вилата е много близо до плажа, както и до главната улица', 'neg_review_content': None}, {'hotel_name': 'Хотел Руж', 'review_rating_score': '8', 'pos_review_content': 'Вилата е на метри от морето и плаж Хармани.Терасата е с прекрасен изглед към морето.Наличен паркинг.Хубав басейн.', 'neg_review_content': 'Липсата на абсорбатор и тента на терасата .'}, {'hotel_name': 'Хотел Руж', 'review_rating_score': '8', 'pos_review_content': 'Локацията е супер.На 10 минути пеша от Лидл,на 2 минути от Плаж Харманите,на 5 минути пеша от Главната улица на Новият град с всички възможни магазини заведения и увеселения за деца.\nЧистота:Супер чисто и спретнато,един от собствениците обикаля от рано сутрин до късно вечер да полива,почиства и поддържа общите части.\nАпартамента,който бяхме наели бе супер чист и спретнат.\nОтношение от обслужването:Хората от които наехме апартамента са супер дружелюбни и винаги готови да помогнат ако имате нужда.Бяхме наели апартамента над тях номер 22 с гледка към басейна и малка но достатъчна тераса.Та бяхме с малко ревящо бебе и бягащо и скачащо дете на 5 годинки.Когато си напускахме се извинихме за създаденият шум,а хората с усмивка ни отговориха,че не са ни чували и да не се притесняваме.\nОбобщение:\nЧисто спретнато,с много добра локация на първа линия до плажът.С дружелюбни хазаи и паркинг за колата ви.За Цената мога да кажа,че ми се струва доста сносна да не кажа евтино за това което получаваме,но това е относително за всеки според възможностите.С много приятен малък и голям басейн където след около 16:00 става сенчесто и много приятно за ползване докато на плажът е жега.\nМного скоро ще резервираме за следващото лято.\nБлагодаря за прекрасното отношение!\nАгоп Калугян', 'neg_review_content': 'Единственото за което съжалявам е че не намерихме това местенце преди няколко години когато бяхме в Созопол отново!'}, {'hotel_name': 'Хотел Руж', 'review_rating_score': '8', 'pos_review_content': 'Хотела е чист и спретнат домакините са много вежливи . Басейна е  поддържан ,хареса ни много и разположението близко е до плажа , до центъра на Стария град се стига за 15 ,20 минути .Ние бяхме семейство с деца и си прекарахме чудесно ще се върнем пак.', 'neg_review_content': None}, {'hotel_name': 'Хотел Руж', 'review_rating_score': '8', 'pos_review_content': 'Местоположението е страхотно,любезни домакини,хубав и чист басейн,в кухнята има абсолютно всякаква посуда,каквато ти дойде на ум,тихо и спокойно място за почивка.С удоволствие бихме повторили.', 'neg_review_content': 'Няма такова нещо.'}, {'hotel_name': 'Хотел Руж', 'review_rating_score': '8', 'pos_review_content': 'Хубава гледка. Просторна тераса', 'neg_review_content': 'Сушилото беше ръждясало и си съсипах хавлиите. Диванът не беше удобен за спане.'}, {'hotel_name': 'Хотел Руж', 'review_rating_score': '8', 'pos_review_content': 'Много хубаво, чисто и уютно студио. Вилата се намира на много добро и комуникативно място.\nОтзивчиви и любезни домакини. Басейнът чист и подържан. Всичко това допринесе за една спокойна и приятна почивка.', 'neg_review_content': None}, {'hotel_name': 'Хотел Руж', 'review_rating_score': '8', 'pos_review_content': 'Приятен апартамент с всичко необходимо, за да се чувствате удобно. Прекрасна гледка към морето. Осигурено място за паркиран ...
# [{'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_review_content': 'Хотелът е разположен на много удобна локация в Созопол. Плажът и Старият град са на 5-10 минути пеша. Имат вкусно обедно меню в ресторанта. Към нашата спалня се откриваше чудесна панорамна гледка към плажа и градът. Добро съотношение спрямо цената, удобствата и локацията.', 'neg_review_content': 'Не ми допадна липсата на асансьор, но това зависи от архитектурата на сградата. Пак бих посетила хотела въпреки това.'}, {'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_review_content': 'Чудесна локация, стаите ни бяха със страхотни гледки към морето. Леглата са големи и удобни, терасите също. Добре обзаведени, с всичко необходимо.', 'neg_review_content': None}, {'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_review_content': 'Местоположението е чудесно в сърцето на стария град Созопол! Персоналът на рецепцията беше много любезен.  Стаята е просторна, чиста и обзаведена много уютно, има всичко необходимо за един приятен престой! В банята бяха осигурени всички необходими принадлежности. Стаята разполага с хладилник, интернетът е добър. Беше осигурено и парко място в близост до хотела. В кухненския бокс към стаята има диванче, микровълнова, кана за вода, котлон и др. Всичко е ИЗКЛЮЧИТЕЛНО чисто! Определено ако се върнем един ден отново, ще изберем същото място!', 'neg_review_content': 'няма'}, {'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_review_content': 'Мястото е прекрасно, чист семеен хотел, разположен в близост до централния плаж и стария град. В стаята имаше всички необходими удобства! Домакините са гостоприемни и много мили! \nПрестоят ни беше чудесен!', 'neg_review_content': None}, {'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_review_content': 'Уютно , чисто , учтиви хора ! Перфектно', 'neg_review_content': None}, {'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_review_content': 'Много  и страхотно място.Препоръчвам!!!!И много добре локация', 'neg_review_content': None}, {'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_review_content': 'Уюта в стаите и гостоприемстото', 'neg_review_content': None}, {'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_review_content': 'Чистотата и големината на стаята. Вежливият персонал и разположението на хотела. Много хубава локация в близост до главната улица и стария град. Наличието на безплатен паркинг. Бихме посетили отново.', 'neg_review_content': 'Като цяло нямаме забележки, една малка препоръка - ще е чудесно да има кафе машина в стаята за да може да започнеш деня си на терасата с чаша кафе.'}, {'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_review_content': 'Единствено локацията  ...', 'neg_review_content': 'Не ми хареса храната в ресторанта...И не ми хареса мястото за паркиране което беше на тротоара...Това си е за притеснение.'}, {'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_review_content': 'Красиво и много чисто място за почивка. Направено с вкус и усет към детайла. Ресторантът към хотела беше много добър, по-добър от повечето в Созопол.', 'neg_review_content': 'На нас ни беше много твърд матракът, но това е въпрос на навик и лично предпочитание.'}, {'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_review_content': 'Стаите са с \nчудесен изглед и чисти.\nРесторанта е много добър.\nХората от хотела са много любезни.', 'neg_review_content': 'Няма такова.'}, {'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_review_content': 'Домакините бяха изключително гостоприемни.\nБлагодаря!\nЧисто, удобно, с изглед към морето.', 'neg_review_content': None}, {'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_review_content': None, 'neg_review_content': 'На стръмно място е разположен ,но обслужването е много добро и си струва.'}, {'hotel_name': 'Хотел Аполония', 'review_rating_score': '10', 'pos_re ...
# [{'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Добро обслужване, стаята се почистваше всеки ден. Усмихнат и мил персонал.', 'neg_review_content': 'Ако не работи вентилаторът постоянно, от сифона в банята се носи неприятна миризма. Няма снимка на гледката от терасата, което малко подвежда за апартамент с изглед към морето, а в действителност гледаш 2 покрива и комините им, и в ъглите едва се подава морето.'}, {'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Всичко! Страшно комуникативно място! Близо до плаж, стар и нов град! Заслужава си!', 'neg_review_content': 'Няма нещо което да не ни е харесало.'}, {'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Много чисто , удобно и приветливо! Стаята беше със страхотно изложение и персонала беше много мил и отзивчив. Бихме повторили пак.', 'neg_review_content': 'Няма такова.'}, {'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Прекрасно местоположение.Близо до плажа, центъра и стария град.Имаше осигурено паркомясто.', 'neg_review_content': None}, {'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Невероятно любезни и учтиви домакини.', 'neg_review_content': None}, {'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Много симпатичен хотел на хубаво място, чисти стаи, бърз нет - съотношението между условия и цена беше отлично. Никакви проблеми, коректен домакин, добра комуникация. Препоръчвам и с удоволствие бих отседнал там отново!', 'neg_review_content': 'Без никакви забележки, всичко беше супер!'}, {'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Удобен, чист , хубав апартамент.\nХотела е буквално до плажа.', 'neg_review_content': None}, {'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Много чист и просторен апартамент с чудесна гледка към морето. Персоналът беше много мил. Ще се върнем отново.', 'neg_review_content': None}, {'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Беше много чисто, дамата на рецепция беше много дружелюбна и приветлива. Съотношението между цената и качеството е изненадващо, дори надхвърли очакванията ми.', 'neg_review_content': None}, {'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Прекрасно, спокойно и уютно хотелче. В апартамента имаше абсолютно всичко необходимо за престой, нищо не ни липсваше. Включително имаше и паркомясто пред самия хотел. Много отзивчива и прекрасна млада дама, благодарение на която престоят ни беше незабравим. Близостта до плажа и до старият град е неоспоримо предимство на този малък, но истински кокетен и чаровен хотел. Надяваме се лятото да успеем да го посетим за по-дълго време! Сърдечно благодарим на домакините и препоръчваме 100% Silver хотел!!!', 'neg_review_content': 'Няма нещо, което да не ни хареса!'}, {'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Всичко ни хареса, апартамента, обзавеждането, локацията. Всичко ни беше удобно и се насладихме на една малка три дневна почивка. Благодаря Ви!', 'neg_review_content': None}, {'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Собствениците са много дружелюбни, мястото е близо до плажа и до търговската улица, чисто е. Имаше най-нужното- хладилник, ютия, сешоар, кана за вода, климатик. Леглото беше удобно и за щастие двойно, а не две допрени легла.', 'neg_review_content': 'Коридорът в нашата стая беше изключително тесен. Мястото сутрин е малко шумно, ако се охлаждате на отворена врата, а не на климатик.'}, {'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Много мили домакини, страхотно разположение, удобни апартаменти.', 'neg_review_content': None}, {'hotel_name': 'Хотел Силвър', 'review_rating_score': '10', 'pos_review_content': 'Хотела е с отлично местоп ...
# [{'hotel_name': 'Вила Весела', 'review_rating_score': '10', 'pos_review_content': 'Всичко беше чудесно. Локацията е перфектна. Бях настанена във фамилната стая на последния етаж с огромна тераса.', 'neg_review_content': 'Предвидете да носите по-малко багаж, понеже няма асансьор :)'}, {'hotel_name': 'Вила Весела', 'review_rating_score': '10', 'pos_review_content': 'Всичко', 'neg_review_content': 'Нищо'}, {'hotel_name': 'Вила Весела', 'review_rating_score': '10', 'pos_review_content': 'Любезни домакинии и добралокация', 'neg_review_content': 'Чиста и с всички удобства стая'}, {'hotel_name': 'Вила Весела', 'review_rating_score': '10', 'pos_review_content': 'Местоположението, много близо и до двата плажа. Стопаните също бяха изключително мили!', 'neg_review_content': None}, {'hotel_name': 'Вила Весела', 'review_rating_score': '10', 'pos_review_content': 'Прекрасно местоположение - на един завой място от плаж "Харманите", пред къщата има градинка с дървета и катерушки, от стаята ни се виждаше залива... Също на пешеходно раззстояние и от централния плаж, където, макар и по-малък, гледката е много живописна и пясъкът е по-фин. Не беше описано в офертата, но във вилата се предлагат кърпи и сешоар, на всеки етаж има дъска за гладене. Стаята беше голяма и удобна, беше чисто. Има кана за топла вода, чаши, хладилник, чинии, нож, вилица, лъжица....На терасата си има масичка, столчета с възглавнички, простор със щипки, даже пепелник-рапан за пушачите....абе всички удобства...В дворчето има столове и масички за почивка, чадър, зеленина. Хазяите са много мили хора, усмихнати и отзивчиви. Чувствахме се чудесно, а синът ми каза, че много му е харесало  - и вилата, и самият Созопол. На мен също.', 'neg_review_content': 'Хазяите предлагат сутрин чай и кафе. Ако може, да има по-голям избор, но това си е екстра и изобщо не е задължително. Наблизо има много места, наистина много, от които човек може да си купи всичко!'}, {'hotel_name': 'Вила Весела', 'review_rating_score': '10', 'pos_review_content': None, 'neg_review_content': 'Можеше да има интернет в стаята'}, {'hotel_name': 'Вила Весела', 'review_rating_score': '10', 'pos_review_content': 'Вила Весела е на много хубаво разположение само на няколко минутки ходене от плажовете и стария град. Персоналът е много мил и отзивчив. Стайте чисти и удобни с прекрасни тераси, някои с изглед към морето.9', 'neg_review_content': None}, {'hotel_name': 'Вила Весела', 'review_rating_score': '10', 'pos_review_content': 'Отличната локация на вилата, любезното отношение на домакините.', 'neg_review_content': None}, {'hotel_name': 'Вила Весела', 'review_rating_score': '10', 'pos_review_content': 'Абсолютно всичко беше на ниво! Никакви оплаквания!', 'neg_review_content': 'Всичко беше отлично!'}, {'hotel_name': 'Вила Весела', 'review_rating_score': '10', 'pos_review_content': 'Собствениците бяха изключително любезни! Въпреки че пристигнахме по - рано, ни помогнаха да се настаним и ни съдействаха за намирането на паркомясто. Стаята беше голяма и удобна а терасата имаше невероятна гледка. Радвам се, че все още има такова добро обслужване в наш курорт и с удоволствие бихме се върнали отново!', 'neg_review_content': None}, {'hotel_name': 'Вила Весела', 'review_rating_score': '10', 'pos_review_content': 'Топ местоположение, на 5 мин. от плажа. Добра гледка от стаята с видимост към морето. Изключително любезни домакини.', 'neg_review_content': 'Като недостатъци мога да изтъкна леглата (не особено удобни) и калъфките на възглавниците (от изкуствена материя, която запотява). Другия минус е, че срещу къщата има зелен кът с детска площадка, на която вечер се събират местните гаменчета, крещят и пускат музика до към полунощ.'}, {'hotel_name': 'Вила Весела', 'review_rating_score': '10', 'pos_review_content': 'Местоположението е перфектно, гледката към морето е отлична.', 'neg_review_content': 'Няма място за паркиране.'}, {'hotel_name': 'Вила Весела', 'review_rating_score': '10', 'pos_review_content': 'Града и материалната база', ...
# [{'hotel_name': 'Хотел Южна Перла', 'review_rating_score': '7', 'pos_review_content': 'Стаите се поддържаха чисти,бельото се сменяше през ден,персоналът беше много любезен.\nХраната беше сравнително евтина.', 'neg_review_content': 'Фитнеса не се поддържаше,беше прашно .'}, {'hotel_name': 'Хотел Южна Перла', 'review_rating_score': '7', 'pos_review_content': 'Местоположеинето е супер. Закуската не беше по мой вкус.', 'neg_review_content': None}, {'hotel_name': 'Хотел Южна Перла', 'review_rating_score': '7', 'pos_review_content': 'Престоят ми хареса, защото търсех спокойствие и релакс. Събуждате се с песните на птиците и морския бриз. Плажът е на 2 крачки и до него се стига по удобна дървена алея. Кафенетата на брега са в унисон с природата и бохемския стил на мястото! Морето и пясъкът бяха много чисти! Има пълна свобода на избор относно свободна зона, само чадър, шатри и други. Цени 25 лв. за чадър с 2 шезлонга. Препорръчвам мястото!', 'neg_review_content': 'Паркинга се заплаща 10 лева за 24 часа и това не ми хареса, но има и безплатен паркинг в страни от хотела! Той е по-трудно достъпен и би могло да се да се измисли решение. Липсваше сладолед в хотела и в близост, това не се хареса на детето!) Имахме проблеми и със собственици които си готвиха под нас и цялата миризма бе навлязла в стаята ни! Миризмата бе нетърпима! За радост, Управителката на хотела се държа много професионално и ни предложи смяна на стаята, компенсация за неудобството! Благодаря за което!'}, {'hotel_name': 'Хотел Южна Перла', 'review_rating_score': '7', 'pos_review_content': None, 'neg_review_content': 'Кучета лаещи.\nМиризма от готвене в апартаментите.'}, {'hotel_name': 'Хотел Южна Перла', 'review_rating_score': '7', 'pos_review_content': 'Местоположението', 'neg_review_content': 'Бариерата, която не се отваряше…'}, {'hotel_name': 'Хотел Южна Перла', 'review_rating_score': '7', 'pos_review_content': 'Разположението на хотела - близостта до морето и отдалечеността от други хотели.', 'neg_review_content': 'Леглото - неудобно, като че ли на пружина. Климатикът не правеше зададената му температура, беше топло в стаята!'}, {'hotel_name': 'Хотел Южна Перла', 'review_rating_score': '7', 'pos_review_content': 'Местоположението на хотела, близостта на плажа и новия бийч клуб. Персоналът отново ни посрещна  усмихнат и отзивчив. Със сигурност ще го посетим отново.', 'neg_review_content': 'Шумните съседи и наличието на домашни любимци от собственици на апартаменти.'}, {'hotel_name': 'Хотел Южна Перла', 'review_rating_score': '7', 'pos_review_content': 'Първите дни закуската беше богата, дори имаше уникални мекици и панирани филии. През луикенда, нещата се промениха тотално. От 20 артикула останаха 5-6 , и това не им правеше голямо впечатление:(', 'neg_review_content': None}, {'hotel_name': 'Хотел Южна Перла', 'review_rating_score': '7', 'pos_review_content': 'Локация. Отношението на един от рецепционистите беше топло и приятелско.', 'neg_review_content': 'Някои неща в стаята/са пред разпад, има нужда от реновиране. \nРаботното време на ресторантът е неприемливо.\nВ 11.40 не можеха да ми сервират нищо, нито в 14.20. Ресторантът работел/сервира храна само между 12 и 14ч.  ( не сме на блок маса, поръчваме и плащаме). Вечерта в 8 вече не работи. Реално казват, че има, но все едно няма ресторант'}, {'hotel_name': 'Хотел Южна Перла', 'review_rating_score': '7', 'pos_review_content': 'Любезен и приветлив персонал. Удобна локация точно до плажа. Просторни стаи.', 'neg_review_content': 'Занемарена база. Душът течеше във всички посоки, но не и на където трябва (оправиха го няколко часа след като казахме на рецепция). Паркингът зад хотела е направо оф-роуд изживяване.'}, {'hotel_name': 'Хотел Южна Перла', 'review_rating_score': '7', 'pos_review_content': 'Уютно хотелче на брега на морето. Добра закуска, любезен персонал. Бях с домашен любимец, който се чувстваше добре и спокоен.', 'neg_review_content': 'Хотела е приятен, но се е е амортизирал с времето.'}, {'hotel_name': 'Хотел Ю ...
# [{'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'Любезни домакини \nХубаво беше,че има осигурено парко-място', 'neg_review_content': None}, {'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'Спокойно!\rТихо!\rУютно!', 'neg_review_content': 'Да има закуска...'}, {'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'Местоположението на хотела е перфектно. Стаята е просторна, чиста,  има и сешоар. Към хотела има паркинг, което е голямо предимство. Рецепционистката беше изключително любезна и отзивчива. Тъй като за първи път отсядахме в Созопол ни обясни ни кои плажовете са подходящи за нас, насочи ни към забележителности и даже ни препоръча ресторанти.', 'neg_review_content': 'Балконът беше тесничък, но се справихме 😁'}, {'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'Хубав хотел със собствен паркинг', 'neg_review_content': None}, {'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'Тих район. Чудесен паркинг.', 'neg_review_content': 'Няма комарници на балконската врата. Душа в банята /пръска в различни посоки/.'}, {'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'Любимо хотелче! Отзивчив и усмихнат персонал!\nТоп локация!\nНе пропускаме всяка година да го посетим!', 'neg_review_content': 'Проблемът е, че топлата вода много бавно достига до горните етажи и няколко пъти ни се случи сутринта да чакаме по 1 час, за да може да се изкъпем с топла вода.'}, {'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'Стаята беше много чиста, хареса ми доброто обслужване от рецепционистката, беше много мила жена. Също ми хареса, че й хотелът разполага с удобен паркинг.', 'neg_review_content': 'Тоалетната в банята при всяко пускане на казанчето, изтичаше вода отзад на тоалетната чиния'}, {'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'Добро местоположение.', 'neg_review_content': 'Няма забележки.'}, {'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'Много любезен персонал\nУдобен матрак\nХубаво кафе на рецепция\nБезплатен паркинг', 'neg_review_content': None}, {'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'Не се предлага закуска', 'neg_review_content': 'Пред хотела все още не е асфалтиран пътя. Но това е работа на общината.'}, {'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'Тихо и спокойно място, в същото време близо до плажовете и центъра на Созопол. Чисти стаи и удобни легла.', 'neg_review_content': 'Прекалено скъпо кафе се предлага на рецепцията от съвсем обикновен кафе автомат.'}, {'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'Всичко много ни хареса. Близо до центъра и плажа. Собствен паркинг.', 'neg_review_content': 'Няма опция за хранене'}, {'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'За 5та година посещавам Siena House и определено чистотата, паркингът и усмихнатият и любезен персонал са плюсовете на мястото. Много добро съотношение цена-качество.', 'neg_review_content': None}, {'hotel_name': 'Хотел Сиена Хаус', 'review_rating_score': '9', 'pos_review_content': 'За разлика от повечето хотели в Созопол, този има собствен безплатен паркинг. Хотелът е приятен и изглежда добре. Стаята ни изглеждаше точно, както на снимките. Леглото и възглавниците са удобни. Има си всичко за приятен престой - климатик, сешоар, малък хладилник, телевизор, сушилка за дрехи и маса с два стола на балкона, гардероб със закачалки, сравнително голямо огледало, пред което има маса тип бюро и стол. Има нощни шкафченца от всяка страна на леглото с контакт и ключ за гасене на осветлението над леглото. Има комарник на единия прозорец, но не и на вратата на балкона. Комарник имаше и на прозорчето на банята. ...
# [{'hotel_name': 'Апартамент А19 в Созополи хилс', 'review_rating_score': '10', 'pos_review_content': 'Всичко!', 'neg_review_content': 'Няма такова нещо.'}, {'hotel_name': 'Апартамент А19 в Созополи хилс', 'review_rating_score': '10', 'pos_review_content': 'Апартамента беше изключително чист, добре оборудван.Домакините са дружелюбни, любезни и разбиращи.', 'neg_review_content': None}, {'hotel_name': 'Апартамент А19 в Созополи хилс', 'review_rating_score': '10', 'pos_review_content': 'Отношението на собствениците. Бяха изключително отзивчиви и направиха престоят ни да е все едно сме в собствената си къща.', 'neg_review_content': None}, {'hotel_name': 'Апартамент А19 в Созополи хилс', 'review_rating_score': '10', 'pos_review_content': 'Изключително уютно и спокойно място. Бях приятно изненадана от обстановката. Има абсолютно всичко, което ви е необходимо ако решите да си приготвяте храната. Домакинята беше изключително любезна. Препоръчвам мястото :)', 'neg_review_content': None}, {'hotel_name': 'Апартамент А19 в Созополи хилс', 'review_rating_score': '10', 'pos_review_content': 'Много чисто и приятно. Апартаментът разполагаше с всичко необходимо, нямаше нещо, което да ни липсва. Много добра комуникация с домакините, изключително любезни и приятни.', 'neg_review_content': None}, {'hotel_name': 'Апартамент А19 в Созополи хилс', 'review_rating_score': '10', 'pos_review_content': 'Супер зареден апартамент,  много любезен домакин всичко е на високо ниво', 'neg_review_content': 'Много далеч от старият град,  но пък е супер спокойно'}, {'hotel_name': 'Апартамент А19 в Созополи хилс', 'review_rating_score': '10', 'pos_review_content': 'Превъзходно!', 'neg_review_content': 'Няма такова!'}, {'hotel_name': 'Апартамент А19 в Созополи хилс', 'review_rating_score': '10', 'pos_review_content': 'Добра локация на тихо и в същото време комуникативно място.\nАпартаментът беше много чист и добре оборудван, с много удобства (имаше абсолютно всичко необходимо). Домакинът е изключително любезен отзивчив човек.', 'neg_review_content': 'Пътят, по който се стига до комплекса е неосветен и определено има нужда от ремонт.'}]
# [{'hotel_name': 'Семеен хотел Корал', 'review_rating_score': '8', 'pos_review_content': 'Закуската беше достатъчна, но еднообразна.\rХареса ми, че имаше осигурено място за паркиране!', 'neg_review_content': 'Нямаше комарник на мокрото помещение.\rТелевизора не работеше добре!\rДобре би било, да има сешоар.'}, {'hotel_name': 'Семеен хотел Корал', 'review_rating_score': '8', 'pos_review_content': 'Добра локация. Има къде да си паркираш автомобила. Стаята беше просторна и чиста. Персонала беше любезен. За съотношение цена - качество е добре.', 'neg_review_content': 'Малко е морално остаряло. Леглата и възглавниците трябва да се подновят.\nЗакуската не ставаше!'}, {'hotel_name': 'Семеен хотел Корал', 'review_rating_score': '8', 'pos_review_content': None, 'neg_review_content': 'Закуската, шум от улицата'}, {'hotel_name': 'Семеен хотел Корал', 'review_rating_score': '8', 'pos_review_content': 'Локацията е добра, стаите бяха прилични .', 'neg_review_content': 'Закуската беше доста оскъдна.'}, {'hotel_name': 'Семеен хотел Корал', 'review_rating_score': '8', 'pos_review_content': 'Мястото', 'neg_review_content': 'Закуската'}, {'hotel_name': 'Семеен хотел Корал', 'review_rating_score': '8', 'pos_review_content': 'Управителят и неговото семейство, които се грижиха за престоя ни, направиха всичко възможно да се чувстваме добре и заради тях всичко мина чудесно. Специално нашата стая беше и с гледка към морето, и благодарение на съдействието на управителя винаги имахме място на паркинга за колата ни. Самият паркинг иначе е малък (само за 6 коли) и има риск да няма място на него.', 'neg_review_content': 'Хотелът е собственост на най-истеричната и нелюбезна жена, с която сме имали неудоволствието да общуваме. Имаше неточност в потвърждението от Booking, което се оказа тяхно недоглеждане, но вместо да ни изслуша, тя вдигна чутовен скандал в 23 ч. вечерта, след като вече се бяхме настанили. \rАко не бяха управителя и семейството му, щяхме да напуснем иначе нелошия хотел. В крайна сметка, благодарение на тях, се разбрахме и настанихме, а на сутранта изяснихме въпроса, но това беше едно от най-неприятните посрещания в хотел, което сме имали досега. За малко да ни откаже от престоя ни там.'}, {'hotel_name': 'Семеен хотел Корал', 'review_rating_score': '8', 'pos_review_content': 'Персонала ,стаята ,организацията,това че се опитвате да ни угодите.', 'neg_review_content': 'Това че , паркирнето е малко трудно ,въпреки че персонала се опитва да уреди нещата.'}, {'hotel_name': 'Семеен хотел Корал', 'review_rating_score': '8', 'pos_review_content': 'Закуската беше добра. Местоположението на хотела е чудесно.', 'neg_review_content': 'Няма нещо което да не ми хареса.'}, {'hotel_name': 'Семеен хотел Корал', 'review_rating_score': '8', 'pos_review_content': 'Топлото отношение на персонала. \nТерасата и изгледа към морето. Със сигурност ще го посетим пак.', 'neg_review_content': 'Няма нещо, което да не ни хареса.'}, {'hotel_name': 'Семеен хотел Корал', 'review_rating_score': '8', 'pos_review_content': 'Персоналът беше учтив и позитивно настроен. Дадоха ни втори ключ с чип въпреки, че не са длъжни. Мястото на хотелът е чудесно. Стаята беше със задоволителен размер.', 'neg_review_content': 'Обзавеждането на стаята е старо и нееднотипно. В банята повечето от уредите бяха пред разпадане. Дръжката на врата от вътрешната страна на банята е откачена. релсата на душа също се разпадаше. Козолата над мивката едва се крепеше. Вентилаторът не работеше. На терасата преградата със съседната тераса е прозрачна, и не създава усещане за уединение. В офертата пише, че има изглед към морето, но фактически между морето и хотела има друг хотел. Ресторантът към хотела не работеше.'}, {'hotel_name': 'Семеен хотел Корал', 'review_rating_score': '8', 'pos_review_content': 'Почти нищо', 'neg_review_content': 'Много неща'}, {'hotel_name': 'Семеен хотел Корал', 'review_rating_score': '8', 'pos_review_content': 'Много учтиви.Невероятен персонал.', 'neg_review_content': None}, {'hotel_na ...
# [{'hotel_name': 'Хотел Роял Калисто', 'review_rating_score': '10', 'pos_review_content': 'Лесно намерихме хотела, паркинга беше на много удобно място.\nРазположението на апартамента в тип мезонет беше интересно, с много пространство. Много ни допаднаха местата с огледала и огромните тераси.', 'neg_review_content': None}, {'hotel_name': 'Хотел Роял Калисто', 'review_rating_score': '10', 'pos_review_content': 'Хотелът е чист, персонала изключително позитивен и локацията е перфектна. Закуската е добра, но всеки ден приблизително еднаква.', 'neg_review_content': 'Работното време на басейна е само от 9 до 19.'}, {'hotel_name': 'Хотел Роял Калисто', 'review_rating_score': '10', 'pos_review_content': 'Обстановката- красиво и стилно, помислено е за всеки детайл, хотелът е близо до плажа, с изглед към морето,  близо е до центъра на града, храната е вкусна и разнообразна, има хубав басейн.', 'neg_review_content': 'Не.'}, {'hotel_name': 'Хотел Роял Калисто', 'review_rating_score': '10', 'pos_review_content': 'Много чист, спретнат, подреден и приятен хотел. Стаите бяха големи, чисти и оборудвани с всичко необходимо. Закуската беше разнообразна и вкусна. Вежлив, отзивчив и усмихнат персонал.', 'neg_review_content': None}, {'hotel_name': 'Хотел Роял Калисто', 'review_rating_score': '10', 'pos_review_content': 'Стаята беше голяма. Имаше достатъчно място и за допълнително легло. Има климатик. Домакините са любезни и на разположение денонощно. От балкона се разкрива прекрасна гледка към морето. Басейнът е чист. Всяка вечер се почиства. Дават се допълни кърпи за басейна. \rЗакуската беше добра. Имаше разнообразна храна, зеленчуци и сезонни плодове. Екипът е от младежи, които непрекъснато отсервират и съдействат на гостите. \rИма и ресторант към хотела, в който няма голямо разнообразие, но за един бърз обяд става.', 'neg_review_content': 'Басейнът работи само до 19 ч. \rХладилникът е много малък. \rМоже да се поставят повече шампоани в банята, например. \rВъзглавниците са ниски и не много удобни.'}, {'hotel_name': 'Хотел Роял Калисто', 'review_rating_score': '10', 'pos_review_content': 'Отлично местоположение. Осигурен паркинг към хотела. Вкусна закуска, разнообразни продукти. Поддържан басейн. Чистотата в стаята, както и в целия комплекс е на ниво. Свеж интериор. Приветлив персонал.', 'neg_review_content': None}, {'hotel_name': 'Хотел Роял Калисто', 'review_rating_score': '10', 'pos_review_content': 'Страхотно място! Запазихме го случайно, но със сигурност попада в листа ни с фаворити. Уютно, спокойно и чисто място, подходящо за семейства с деца или хора,които търсят уединение. Чистота е на високо ниво,почиства се постоянно и качествено. Отзивчив персонал и страхотно обслужване.Препоръчваме с две ръце!', 'neg_review_content': 'Няма нещо,което да не ни е харесало.'}, {'hotel_name': 'Хотел Роял Калисто', 'review_rating_score': '10', 'pos_review_content': 'Чист и спретнат хотел с добра локация, близо е до двата плажа. Широки стаи с просторни бани, големи и удобни легла. За нас беше голям плюс, че нямаше вана в банята, винаги предпочитаме да е с душ-кабина. Момичето на рецепция беше много учтиво и обясни с подробности всичко, което ни интересуваше. Закуската беше достатъчна разнообразна, предлагаха безлактозно мляко, което е добре за хора с непоносимост. Нямаше проблем при по-късното ни настаняване, имаше кой да ни посрещне.', 'neg_review_content': 'Кухнята на хотела работи до 20ч, но бяхме предварително уведомени. На пешеходно разстояние имаше отворени заведения.'}, {'hotel_name': 'Хотел Роял Калисто', 'review_rating_score': '10', 'pos_review_content': 'Отношението на персонала си личи още от първата минута.Адекватни,отзивчиви и усмихнати.', 'neg_review_content': 'Нямаше нещо, което да не допадне на мен и семейството ми.'}, {'hotel_name': 'Хотел Роял Калисто', 'review_rating_score': '10', 'pos_review_content': 'Персоналът беше много мил. Хотелът е много чист и закуската беше разнообразна и вкусна.', 'neg_review_content': None}, {'hotel_name': 'Хот ...
# [{'hotel_name': 'Хотел Аполис', 'review_rating_score': '9', 'pos_review_content': 'Персоналът беше учтив и приветлив. Близо до плажа.', 'neg_review_content': 'Съотношението цена- качество НЕ отговаря.\nХотелът се нуждае от ремонт. Стаята беше захабена, със следи от течове и петна по стените. Душ кабината е тясна, а водата излизаше навсякъде, докато се къпеш. Или имаше теч, или  наклонът за отичане на водата не е правилен ( непрекъснато имаше локва в средата на банята).'}, {'hotel_name': 'Хотел Аполис', 'review_rating_score': '9', 'pos_review_content': 'Хубав и добре подържан хотел.\nМного е близо до плаж Харманите     \nПРИЕМАТ ДОМАШНИ ЛЮБИМЦИ !!!', 'neg_review_content': 'Няма нито една кафе машина или друг тип Вендинг автомат.Няма поне една закуската.'}, {'hotel_name': 'Хотел Аполис', 'review_rating_score': '9', 'pos_review_content': 'Местоположението е много добро. На 300 метра от плажа.\nСъотношението цена качество отговаря', 'neg_review_content': None}, {'hotel_name': 'Хотел Аполис', 'review_rating_score': '9', 'pos_review_content': None, 'neg_review_content': 'Банята беше дастя зяхабена /в частта си при душа./.За разлика от тоалетната чиния и мивката, батерията на душа изобщо не беше чистена доста отдавна.'}, {'hotel_name': 'Хотел Аполис', 'review_rating_score': '9', 'pos_review_content': 'Да', 'neg_review_content': 'Не'}, {'hotel_name': 'Хотел Аполис', 'review_rating_score': '9', 'pos_review_content': 'Само това че е близо до  плажа', 'neg_review_content': 'Забележките са много нямам толкова време за писане'}, {'hotel_name': 'Хотел Аполис', 'review_rating_score': '9', 'pos_review_content': 'Персонала беше много любезен стаята с прилични размери препоръчвам', 'neg_review_content': None}]
# ...
# [{'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': 'Хубава локация, сравнително широки стаи. Питаха ни дали искаме почистване.', 'neg_review_content': 'Нямаше комарници и стаята се пълнеше с комари. В банята нямаше нито една закачалка. В коридора беше поставена ютия за общо ползване, която обаче не работеше.'}, {'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': 'Добра локация, чисто, приятно отношение от страна на собственика.\nПриятна тераса. Напълно съответства на цената.', 'neg_review_content': 'Много тясно, липса на контакти.'}, {'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': None, 'neg_review_content': 'Случихме на доста шумна компания по време на престоя ни. Прибираха се в 5:20-30 сутринта и то така, че да ги чуе цялата къща. Две вечери подред ни събуждаха'}, {'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': 'Много приятно място за релакс със добър и вежлив домакин.Наблизо има много магазини,заведения за бързо хранене и е близо до плажа Хармани.Препоръчвам го😊', 'neg_review_content': None}, {'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': 'Всичко ни хареса освен това ме тераските бяха реко тесни. Бяхме 5 момчета в две стаи и едвам седяхме на едната тераса. Също така е хубаво да има и навесме някакво, защото след 12 на обяд не се стоеше на терасата.', 'neg_review_content': None}, {'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': 'Изключително чисто и приветливо място! Обзавеждането, мястото, чистотата, тишината и хубавата локация, направиха престоя ни повече от приятен! Всичко описано е налично и в добро състояние! Много сме доволни, 10месечното ни бебе също беше доволно!', 'neg_review_content': 'Нямаме забележи!'}, {'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': 'Чисто,удобно и уютно.Домакинът беше наистина отзивчив и гостоприемен,съдейства при ситуации.\nЛокацията е много удобна,на тиха улица и на пешеходно разстояние до плажа,в близост има всичко необходимо-магазини,заведения,аптеки.', 'neg_review_content': None}, {'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': 'Всичко беше на високо ниво.', 'neg_review_content': 'Няма такова.'}, {'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': 'удобна локация, много добро обзавеждане и хигиена.', 'neg_review_content': 'в 2:00 сутринта ни казаха да си съберем багажа и да напуснем, тъй като сме пречели на останалите гости, но собствениците не бяха проучили точно кои техни гости бяха отговорни за шумотевицата! това е недопустимо! ритаха ни куфарите и ни стъпкаха багажа!'}, {'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': 'Добро местоположение.', 'neg_review_content': 'Неприятна миризма в стаята още при настаняването, стаята не беше проветрявана отдавна. Миризма на мухъл в цялата стая и в банята. Грубо отношение от страна на домакина, не обясни нища относно удобствата на мястото за настаняване, както се държа грубо, че се настанихме по - късно (около 19:00).'}, {'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': 'мястото е със чудесна локация близо до плажа и до центъра.Чисто и с много удобни легла.', 'neg_review_content': None}, {'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': 'Имаше прекрасна тераска.', 'neg_review_content': 'Леглото (разтегаемият фотьойл) беше изключително некомфортно, вратата на банята не се затваряше и топлата вода се изчерпваше след едно къпане. Имаше и хлебарки. Не минаваха да сменят чаршафи или кърпи, което е некомфортно, когато отсядате за по-дълго време.'}, {'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': 'Най-много ми хареса, че ни приеха с кучето', 'neg_review_content': 'Няма нещо, което да не ми хареса.'}, {'hotel_name': 'Къща Арес', 'review_rating_score': '7', 'pos_review_content': None, 'neg_ ...
# [{'hotel_name': 'Вила Quiet Bay', 'review_rating_score': '10', 'pos_review_content': 'Стаята е просторна, банята също. В стаята имаше малък хладилник, не мини витрина както в повечето хотели. Има кана за топла вода. Телевизорът е  доста по- голям от обичайните с много добра телевизия с възможност за гледане на минали предавания.', 'neg_review_content': None}, {'hotel_name': 'Вила Quiet Bay', 'review_rating_score': '10', 'pos_review_content': 'Панорамна гледка от терасата към морето, осигурен паркинг, чиста и просторна стая. Страхотно кафе, фреш бар и скара пред вилата. Момичето от рецепция беше любезно и усмихнато, настани ни безпроблемно и навреме. Вилата се намира на 10тина минутки пеш от плажа на Каваци, което за нас беше супер.', 'neg_review_content': 'Шумът от другите стаи и коридора се чува доста силно, дори покашлянето на съседите. Четейки другите коментари, май сме случили на съобразителни и културни гости, защото престоят ни беше приятен и спокоен.'}, {'hotel_name': 'Вила Quiet Bay', 'review_rating_score': '10', 'pos_review_content': 'Много чисто, приятно с изглед към морето и много любезни домакини.', 'neg_review_content': 'Нямаме забележки.'}, {'hotel_name': 'Вила Quiet Bay', 'review_rating_score': '10', 'pos_review_content': 'Гледка, местоположение', 'neg_review_content': None}, {'hotel_name': 'Вила Quiet Bay', 'review_rating_score': '10', 'pos_review_content': 'басейна има нужда от малко по добра поддръжка. другото си е ок', 'neg_review_content': None}, {'hotel_name': 'Вила Quiet Bay', 'review_rating_score': '10', 'pos_review_content': 'Стаите бяха хубави и удобни, под хотела има барче и скара. Басейна е достатъчно голям. Навеса с маси и столове до басейна е перфектен за мохабети.', 'neg_review_content': 'На 15 минути пеша е от плажа, няма пряк или директен път.'}, {'hotel_name': 'Вила Quiet Bay', 'review_rating_score': '10', 'pos_review_content': 'Хотела беше добър, удобно, чисто, уютно, персонала беше млад, учтив, услужлив и мил. Гледката беше добра. Терасата беше малка, но достатъчна. Не ни е липсвало нищо. Пред хотела има малка каравана за храна, в която изненадващо храната беше добра. Най-прекрасната безалкохолна джинджифилова бира :)', 'neg_review_content': 'Пише че е забранено за домашни животни, но при престоя си там, имаше две кучета, едното от които си свърши изненадващо голямата работа зад шезлонга ми на басейна.\nХотела е далеч от плаж Каваците. Навръщане е голям наклона нагоре. Далеч е от заведенията и до гарата на Созопол се стига за 40 минути пеш. Много е пуст района, без светлини по главната улица и тротоари, ако се връщате от заведенията на плажа пеш. Другия вариант е по плажа.'}, {'hotel_name': 'Вила Quiet Bay', 'review_rating_score': '10', 'pos_review_content': 'Топ локация и персонал!', 'neg_review_content': 'Стените между стаите сякаш са от вестник! Чува се всичко!'}, {'hotel_name': 'Вила Quiet Bay', 'review_rating_score': '10', 'pos_review_content': 'Апартамента беше изключително удобен, просторен и добре обзаведен - имахме всичко нужно за прекрасен престой. Страхотна тераса със страхотна гледка, перфектен басейн. Момичето на рецепцията - изключителна! А пред хотела правят най-вкусните смутита. Удобният паркинг също е плюс.', 'neg_review_content': 'Останах много доволна.'}, {'hotel_name': 'Вила Quiet Bay', 'review_rating_score': '10', 'pos_review_content': None, 'neg_review_content': 'Единственото нещо, което не харесахме беше, че на няколко от кърпите имаше петна. Всичко останало е супер!'}, {'hotel_name': 'Вила Quiet Bay', 'review_rating_score': '10', 'pos_review_content': 'Хубаво и приятно място, чисто и спокойно.', 'neg_review_content': 'Wifi не беше наличен.'}, {'hotel_name': 'Вила Quiet Bay', 'review_rating_score': '10', 'pos_review_content': 'Настаниха ни по-рано. Момичето на рецепция беше много мила и любезна! Стаята е голяма, светла и просторна с гледка към морето.', 'neg_review_content': 'Дивана беше замърсен'}, {'hotel_name': 'Вила Quiet Bay', 'review_rating_score': '10', 'pos_revi ...
# [{'hotel_name': 'Семеен хотел Венис', 'review_rating_score': '7', 'pos_review_content': 'Доволен съм от мястото, чисто и спретнато. Близо до центъра и стария град,', 'neg_review_content': 'На по-високите етажи малко налягането на водата не беше както трябва,но не е болка за умиране.\rМалко с паркирането е сложно.'}, {'hotel_name': 'Семеен хотел Венис', 'review_rating_score': '7', 'pos_review_content': 'Чисто и подредено.', 'neg_review_content': 'Не ми предложиха паркинг място, а имаха 2.'}, {'hotel_name': 'Семеен хотел Венис', 'review_rating_score': '7', 'pos_review_content': 'Намира се лесно и хотелът е в спокойна част. Имаше хубава сенчеста градина, любезен персонал и нашата стая беше с прекрасен балкон и гледка.', 'neg_review_content': 'Усеща се лека миризма от банята, но при затваряне на врата и отваряне на прозореца в нея няма проблем. За съжаление няма много добра изолация в стаята, а в банята се чува всичко от други стаи, но това също не беше голям проблем за нас.'}, {'hotel_name': 'Семеен хотел Венис', 'review_rating_score': '7', 'pos_review_content': 'Гледка към морето', 'neg_review_content': None}, {'hotel_name': 'Семеен хотел Венис', 'review_rating_score': '7', 'pos_review_content': 'Отношението е страхотно! Хотела е страхотен.', 'neg_review_content': None}, {'hotel_name': 'Семеен хотел Венис', 'review_rating_score': '7', 'pos_review_content': 'Разположен на тиха улица с изглед към морето. Любезен, отзивчив персонал. Препоръчвам!', 'neg_review_content': None}, {'hotel_name': 'Семеен хотел Венис', 'review_rating_score': '7', 'pos_review_content': 'Местоположението е окей. Климатикът работеше.', 'neg_review_content': 'Снимките не само не отговарят на реалните условия, но и факта че липсват снимки на баните е показателен. Баните в действителност са малки и некомфортни (жълта дъска на тоалетната, мръсни плочки и тн.). Леглото беше ужасно неудобно, потъваше когато седнеш - предполагам счупена подматрачна рамка. Ресните бяха изпокъсани и не скриваха добре слънцето.'}]
# [{'hotel_name': 'Хотел Голдън Плейс', 'review_rating_score': '7', 'pos_review_content': 'Бяхме настанени в новото крило на хотела. Беше чисто с хубава мебелировка, санитария, климатик. С удобно излизане в двора на хотела', 'neg_review_content': 'Проблем имаше с канализацията, връщаше миризмата, вероятно защото бяхме на приземен етаж (първи)'}, {'hotel_name': 'Хотел Голдън Плейс', 'review_rating_score': '7', 'pos_review_content': 'Локацията на хотела, закуската, басейна,.', 'neg_review_content': 'Натрапчивия и безполезен персонал, които беше на почивка повече от почиващите и постоянно между нас. Хигиенната е на ниско ниво. Банята ни беше в окаяно състояние и за тотален ремонт, без консуматив за къпане.. Хубав хотел, но занемарен.'}, {'hotel_name': 'Хотел Голдън Плейс', 'review_rating_score': '7', 'pos_review_content': 'Много добро местоположение на хотела. Любезно обслужване. Много добра закуска.', 'neg_review_content': 'Банята има нужда от ремонт. Терасата е разположена на стълбищната площадка при входа на ресторанта.'}, {'hotel_name': 'Хотел Голдън Плейс', 'review_rating_score': '7', 'pos_review_content': 'Почти всичко ни хареса.Стаята беше чиста,кърпите се сменяха редовно.\nПлажа беше близо. Обедното меню също ни хареса.Закуската беше добра,кафето също🙂', 'neg_review_content': 'Нямаше места за паркиране,за това е хубаво е предварително да се запазва.\nНа нашата тераса имаше гнезда на лястовици и постоянно си вършеха работата над масата и по столовете,абсурд да седнеш на терасата. \nНе ни допадна отношението на барманката и сервитьорките, усмихнати са да,но не изчакват да се изкажеш, бавят се,чудят се коя да вземе поръчката,забравят все нещо да ти донесат.'}, {'hotel_name': 'Хотел Голдън Плейс', 'review_rating_score': '7', 'pos_review_content': 'Локацията на хотела е много добра - на 4-5 мин от плаж Каваци. Стаята в хотела беше голяма и чиста. Банята също беше достатъчно голяма и имаше сешоар. В коридора дори имаше дъска за гладене и ютия, което е удобство, в случай, че някой има нужда от тези неща. Закуската беше вкусна и имаше голям избор. Хората също бяха отзивчиви и усмихнати.', 'neg_review_content': 'Храната в ресторанта беше вкусна, но чакахме доста време за приготвянето й (около час, при положение, че бяхме поръчали таратор, салата и тиквички. Плюс, нямаше други клиенти в ресторанта).'}, {'hotel_name': 'Хотел Голдън Плейс', 'review_rating_score': '7', 'pos_review_content': 'Отношението на персонала беше добро, локацията е близо до плажа и доста удобна. Има платен паркинг за 10 лв. на ден и възможността да паркираш безплатно в уличния хаос, наречен Буджака.', 'neg_review_content': 'Стаята ни беше шумна (чувахме ясно кога съседите взимат душ), закуската беше просто приемлива. Компромисно качество на стаята.'}, {'hotel_name': 'Хотел Голдън Плейс', 'review_rating_score': '7', 'pos_review_content': 'Локация, храна, персонал, басейн.', 'neg_review_content': None}, {'hotel_name': 'Хотел Голдън Плейс', 'review_rating_score': '7', 'pos_review_content': 'Стаята беше чиста, от стаята и терасата има страхотна гледка към морето. Имахме и закуска, която беше много добра, за разлика от други места беше видно, че продуктите които ползват не са най-евтините. Стаята се чистеше всеки ден.', 'neg_review_content': 'Стъклопакета на прозорците беше развален и въпреки, че прозорците са чисти всъщност изглездаха много мръсни. Това разваля цялостната вузия на стаята. Собствениците трябва да помислят за смяната им и то възможно най-скоро.'}, {'hotel_name': 'Хотел Голдън Плейс', 'review_rating_score': '7', 'pos_review_content': 'Престоят ни в хотела беше чудесен! Стаите изглеждат точно като на снимките, които са показани в сайта. Всяка стая разполага с тераса с две столчета и маса, сушилка за дрехите, пепелник за пушачите. Гледката към морето е супер! \rПри настаняването ни попитаха дали бихме искали да ползваме паркинга срещу 10 лв. на ден, като всяко парко място се запазва с катинар. Отказахме, защото имаше много свободни места на улицата срещу ...

# %%
hotels_reviews_df = pd.DataFrame(all_reviews)

# %%
hotels_reviews_df.to_csv("data/reviews_hotels_data.csv")

# %%
hotels_reviews_data = pd.read_csv("data/reviews_hotels_data.csv")

# %% [markdown]
# ### Results

# %% [markdown]
# Structured data:

# %%
hotels_data_df.sample(5)
# Out:
#                    hotel_name  hotel_stars_count location  rating  \
# 62       Семеен хотел Калипсо                3.0  Созопол     NaN
# 29               Хотел Боруна                3.0  Созопол     NaN
# 193          Хотел Блу Ориндж                NaN  Созопол     8.2
# 20                  Къща Арес                3.0  Созопол     8.1
# 97   Комплекс Вили над залива                3.0  Созопол     9.5
#
#           room_type1  occupancy1 summer_price1       room_type2  occupancy2  \
# 62   стандартна стая         2.0         70 лв              NaN         NaN
# 29   стандартна стая         2.0        100 лв  стандартна стая         3.0
# 193  стандартна стая         2.0        210 лв              NaN         NaN
# 20   стандартна стая         2.0         80 лв  стандартна стая         3.0
# 97              вила         6.0        380 лв              NaN         NaN
#
#     summer_price2 room_type3  occupancy3 summer_price3  \
# 62            NaN        NaN         NaN           NaN
# 29         150 лв     студио         4.0        140 лв
# 193           NaN        NaN         NaN           NaN
# 20         120 лв     студио         4.0        160 лв
# 97            NaN        NaN         NaN           NaN
#
#                                         amenities_list
# 62   ['телевизор', 'кабелна тв', 'климатик', 'хлади...
# 29   ['паркинг', 'ресторант', 'телевизор', 'кабелна...
# 193  ['открит басейн', 'паркинг', 'ресторант', 'ани...
# 20   ['телевизор', 'кабелна тв', 'сателитна тв', 'х...
# 97   ['открит басейн', 'паркинг', 'детски кът', 'де...

# %% [markdown]
# Unstructured data:

# %%
hotels_reviews_data.sample(5)
# Out:
#       Unnamed: 0                       hotel_name  review_rating_score  \
# 170          170                 Хотел Сиена Хаус                    9
# 1617        1617                Хотел Лагуна Бийч                    8
# 991          991                  Хотел Св. Зосим                   10
# 769          769  Ваканционно селище Санта Марина                    9
# 2137        2137               Хотел Голдън Плейс                    7
#
#                                      pos_review_content  \
# 170   Стаите са големи, има паркинг, имахме възможно...
# 1617  1.Най-напред изключително любезно обслужване о...
# 991    Хората в хотела бяха много усмихнати и любезни !
# 769   Просторен апартамент, с 2 телевизора, приятна ...
# 2137  Чистота, комфорт, бутиков стил на стаите и бли...
#
#                                      neg_review_content
# 170   Няма асансьор и това следва да се упомене, защ...
# 1617  Паркингът е максимално оползотворен, но не е с...
# 991   Единствената ми забележка е, че трябва да има ...
# 769   Споделих вече някои впечатления на ръководство...
# 2137                                                NaN
